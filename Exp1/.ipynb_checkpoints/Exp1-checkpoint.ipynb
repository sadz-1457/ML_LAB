# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import warnings,itertools
from scipy import stats
from sklearn.feature_selection import mutual_info_classif,mutual_info_regression
import os

os.makedirs("Graphs", exist_ok=True)
_original_show = plt.show
plt.show = lambda *args, **kwargs: (plt.savefig(f"Graphs/{plt.gca().get_title() or f'Figure_{plt.gcf().number}'}.png", dpi=600, bbox_inches="tight"), _original_show(*args, **kwargs))


fontname='Times New Roman'
if fontname not in {f.name for f in fm.fontManager.ttflist}:
    warnings.warn(f"{fontname} not found, using DejaVu Serif")
    fontname='DejaVu Serif'

maxcols=3
cellwidth=5
cellheight=4
singlesize=(8,5)
topn=6

def setGraphStyle():
    sns.set_style('whitegrid')
    plt.rcParams['font.family']=fontname
    plt.rcParams['font.size']=15
    plt.rcParams['axes.labelweight']='bold'
    plt.rcParams['axes.titlesize']=15
    plt.rcParams['figure.dpi']=150

def gridAxes(n):
    ncols=min(maxcols,n)
    nrows=int(np.ceil(n/ncols))
    fig,axes=plt.subplots(nrows,ncols,figsize=(cellwidth*ncols,cellheight*nrows))
    axes=np.array(axes).reshape(-1)
    return fig,axes

def showFig(fig):
    fig.tight_layout()
    plt.show()
    plt.close(fig)

def datasetOverview(df):
    rows,cols=df.shape
    names=df.columns.tolist()
    types=df.dtypes.astype(str).tolist()
    return rows,cols,names,types

def checkMissing(df):
    miss=df.isnull().sum()
    dup=df.duplicated().sum()
    single=[c for c in df.columns if df[c].nunique()==1]
    empty=[c for c in df.columns if df[c].isnull().all()]
    mixed=[]
    obj=df.select_dtypes(include=['object','string']).columns
    for c in obj:
        if c in empty:
            continue
        s=df[c].dropna().astype(str)
        if s.empty:
            continue
        if s.str.match(r'^-?\d+(\.\d+)?$').all():
            mixed.append(c)
    return miss,dup,single,empty,mixed

def analyzeNumeric(df):
    num=df.select_dtypes(include=['number'])
    if num.empty:
        return None
    summary=num.describe().T
    summary=summary.rename(columns={'mean':'Mean','std':'Std','min':'Min','max':'Max','50%':'Median','25%':'Q1','75%':'Q3'})
    summary['Mode']=num.mode().iloc[0]
    summary['Range']=summary['Max']-summary['Min']
    summary['Skewness']=num.skew()
    summary['Kurtosis']=num.kurt()
    cols=['Mean','Median','Mode','Std','Min','Max','Q1','Q3','Range','Skewness','Kurtosis']
    return summary[cols]

def analyzeCategorical(df):
    cat=df.select_dtypes(include=['object','string','category'])
    if cat.empty:
        return None
    data=[]
    for c in cat.columns:
        unique=cat[c].nunique()
        mode=cat[c].mode()
        top=mode.iloc[0] if not mode.empty else None
        freq=cat[c].value_counts().iloc[0] if not cat[c].value_counts().empty else 0
        data.append([c,unique,top,freq])
    return pd.DataFrame(data,columns=['Column','Unique','Top Value','Frequency'])

def analyzeNormality(df,alpha=0.05):
    num=df.select_dtypes(include=['number'])
    if num.empty:
        return None
    rows=[]
    for c in num.columns:
        data=num[c].dropna()
        if len(data)<3:
            continue
        sample=data.sample(min(len(data),5000),random_state=42)
        statval,p=stats.shapiro(sample)
        rows.append([c,statval,p,'Normal' if p>alpha else 'Not Normal'])
    return pd.DataFrame(rows,columns=['Column','Statistic','P-Value','Result'])

def mutualInfoAnalysis(df,target):
    if target not in df.columns:
        return None
    num=df.select_dtypes(include=['number']).drop(columns=[target],errors='ignore')
    if num.empty:
        return None
    X=num.fillna(num.median())
    y=df[target]
    if y.dtype=='object' or str(y.dtype)=='category' or y.nunique()<20:
        yenc=y.astype('category').cat.codes
        mi=mutual_info_classif(X,yenc,random_state=42)
    else:
        mi=mutual_info_regression(X,y,random_state=42)
    return pd.DataFrame({'Feature':num.columns,'Mutual Information':mi}).sort_values('Mutual Information',ascending=False).reset_index(drop=True)

def detectOutliers(df):
    num=df.select_dtypes(include=['number'])
    if num.empty:
        return None
    data=[]
    for c in num.columns:
        q1=num[c].quantile(0.25)
        q3=num[c].quantile(0.75)
        iqr=q3-q1
        low=q1-1.5*iqr
        high=q3+1.5*iqr
        count=((num[c]<low)|(num[c]>high)).sum()
        data.append([c,count])
    return pd.DataFrame(data,columns=['Column','Outlier Count'])

def correlationAnalysis(df):
    num=df.select_dtypes(include=['number'])
    return num.corr() if not num.empty else None

def highCorrFeatures(df,limit=0.8):
    num=df.select_dtypes(include=['number'])
    if num.empty:
        return None
    corr=num.corr().abs()
    pairs=[]
    for i in range(len(corr.columns)):
        for j in range(i+1,len(corr.columns)):
            val=corr.iloc[i,j]
            if val>=limit:
                pairs.append([corr.columns[i],corr.columns[j],val])
    return pd.DataFrame(pairs,columns=['Feature1','Feature2','Correlation'])

def classDistribution(df,target):
    return df[target].value_counts() if target in df.columns else None

def plotTargetOverview(df,target,maxcats=30):
    if target not in df.columns:
        print(f'plotTargetOverview: {target} not in dataframe, skipped')
        return
    nunique=df[target].nunique()
    if df[target].dtype.name in ('object','category') or nunique<=maxcats:
        plotClassDistribution(df,target)
    else:
        print(f'plotTargetOverview: target has {nunique} unique values, treating as continuous - showing distribution histogram instead of class bars')
        plotHistogram(df,cols=[target])

def plotClassDistribution(df,target,maxcats=30):
    setGraphStyle()
    if target not in df.columns:
        print(f'plotClassDistribution: {target} not in dataframe, skipped')
        return
    counts=df[target].value_counts()
    if len(counts)>maxcats:
        print(f'plotClassDistribution: target has {len(counts)} unique values (>{maxcats}), skipped - this looks like a continuous target, use plotHistogram instead')
        return
    fig,ax=plt.subplots(figsize=singlesize)
    ax.bar(counts.index.astype(str),counts.values,color='#4C72B0')
    ax.tick_params(axis='x',rotation=45,labelsize=10)
    ax.set_xlabel(target)
    ax.set_ylabel('Count')
    ax.set_title(f'Class Distribution: {target}')
    showFig(fig)

def selectImportantFeatures(df,target=None,n=topn,midf=None):
    num=df.select_dtypes(include=['number'])
    if target is not None and target in num.columns:
        num=num.drop(columns=[target])
    if num.empty:
        return []
    if target is not None and target in df.columns:
        mi=midf if midf is not None else mutualInfoAnalysis(df,target)
        if mi is not None and not mi.empty:
            return mi['Feature'].head(n).tolist()
    return num.var().sort_values(ascending=False).head(n).index.tolist()

def plotHistogram(df,cols=None):
    setGraphStyle()
    num=df.select_dtypes(include=['number'])
    if cols is not None:
        num=num[[c for c in cols if c in num.columns]]
    if num.empty:
        print('plotHistogram: no numeric columns, skipped')
        return
    fig,axes=gridAxes(len(num.columns))
    for i,c in enumerate(num.columns):
        axes[i].hist(num[c].dropna(),bins=30,color='#4C72B0',edgecolor='white')
        axes[i].set_xlabel(c)
        axes[i].set_ylabel('Frequency')
        axes[i].set_title(f'Histogram of {c}')
    for j in range(len(num.columns),len(axes)):
        fig.delaxes(axes[j])
    showFig(fig)

def plotBoxplot(df,cols=None):
    setGraphStyle()
    num=df.select_dtypes(include=['number'])
    if cols is not None:
        num=num[[c for c in cols if c in num.columns]]
    if num.empty:
        print('plotBoxplot: no numeric columns, skipped')
        return
    fig,axes=gridAxes(len(num.columns))
    for i,c in enumerate(num.columns):
        axes[i].boxplot(num[c].dropna(),patch_artist=True,boxprops=dict(facecolor='#DD8452'))
        axes[i].set_ylabel(c)
        axes[i].set_title(f'Boxplot of {c}')
    for j in range(len(num.columns),len(axes)):
        fig.delaxes(axes[j])
    showFig(fig)

def plotBargraph(df,cols=None):
    setGraphStyle()
    cat=df.select_dtypes(include=['object','string','category'])
    if cols is not None:
        cat=cat[[c for c in cols if c in cat.columns]]
    if cat.empty:
        print('plotBargraph: no categorical columns, skipped')
        return
    fig,axes=gridAxes(len(cat.columns))
    for i,c in enumerate(cat.columns):
        vc=cat[c].value_counts().head(15)
        axes[i].bar(vc.index.astype(str),vc.values,color='#55A868')
        axes[i].tick_params(axis='x',rotation=45,labelsize=10)
        axes[i].set_xlabel(c)
        axes[i].set_ylabel('Count')
        axes[i].set_title(f'Bar Chart of {c}')
    for j in range(len(cat.columns),len(axes)):
        fig.delaxes(axes[j])
    showFig(fig)

def plotScatter(df,pairs=None,maxpairs=6):
    setGraphStyle()
    num=df.select_dtypes(include=['number'])
    cols=list(num.columns)
    if len(cols)<2:
        print('plotScatter: fewer than 2 numeric columns, skipped')
        return
    if pairs is None:
        pairs=list(itertools.combinations(cols,2))[:maxpairs]
    fig,axes=gridAxes(len(pairs))
    for i,(a,b) in enumerate(pairs):
        axes[i].scatter(num[a],num[b],alpha=0.6,color='#8172B2',edgecolor='white',linewidth=0.3)
        axes[i].set_xlabel(a)
        axes[i].set_ylabel(b)
        axes[i].set_title(f'{a} vs {b}')
    for j in range(len(pairs),len(axes)):
        fig.delaxes(axes[j])
    showFig(fig)

def plotHeatmap(df,cols=None):
    setGraphStyle()
    num=df.select_dtypes(include=['number'])
    if cols is not None:
        num=num[[c for c in cols if c in num.columns]]
    if num.shape[1]<2:
        print('plotHeatmap: fewer than 2 numeric columns, skipped')
        return
    corr=num.corr()
    fig,ax=plt.subplots(figsize=singlesize)
    sns.heatmap(corr,annot=True,fmt='.2f',cmap='coolwarm',square=True,cbar_kws={'label':'Correlation'},ax=ax,annot_kws={'fontsize':9,'fontname':fontname})
    ax.tick_params(axis='x',rotation=45,labelsize=10)
    ax.tick_params(axis='y',rotation=0,labelsize=10)
    ax.set_xlabel('Features')
    ax.set_ylabel('Features')
    ax.set_title('Correlation Heatmap')
    showFig(fig)

def plotMissingValues(df):
    setGraphStyle()
    miss=df.isnull().sum()
    miss=miss[miss>0].sort_values(ascending=False)
    if miss.empty:
        print('plotMissingValues: no missing values, skipped')
        return
    fig,ax=plt.subplots(figsize=singlesize)
    ax.bar(miss.index.astype(str),miss.values,color='#C44E52')
    ax.tick_params(axis='x',rotation=45,labelsize=10)
    ax.set_xlabel('Column')
    ax.set_ylabel('Missing Count')
    ax.set_title('Missing Values by Column')
    showFig(fig)

def plotOutliers(df):
    setGraphStyle()
    out=detectOutliers(df)
    if out is None or out['Outlier Count'].sum()==0:
        print('plotOutliers: no outliers detected, skipped')
        return
    fig,ax=plt.subplots(figsize=singlesize)
    ax.bar(out['Column'],out['Outlier Count'],color='#DD8452')
    ax.tick_params(axis='x',rotation=45,labelsize=10)
    ax.set_xlabel('Column')
    ax.set_ylabel('Outlier Count')
    ax.set_title('Outlier Count per Column (IQR method)')
    showFig(fig)

def generateCorePlots(df,target=None,n=topn,midf=None):
    important=selectImportantFeatures(df,target,n,midf=midf)
    if target is not None:
        plotTargetOverview(df,target)
    plotHeatmap(df)
    plotHistogram(df,cols=important)
    plotBoxplot(df,cols=important)

def generateAllPlots(df,target=None,n=topn,midf=None):
    plotMissingValues(df)
    generateCorePlots(df,target,n,midf=midf)
    plotOutliers(df)
    plotBargraph(df)
    plotScatter(df)

def edaSummary(df,target=None,full=False,n=topn):
    rows,cols,names,types=datasetOverview(df)
    miss,dup,single,empty,mixed=checkMissing(df)
    mi=mutualInfoAnalysis(df,target) if target is not None else None
    summary={"Rows":rows,"Columns":cols,"Column Names":names,"Data Types":types,"Missing Values":miss,
    "Duplicate Rows":dup,"Single Value Columns":single,"Empty Columns":empty,"Mixed Type Columns":mixed,
    "Numerical Summary":analyzeNumeric(df),"Categorical Summary":analyzeCategorical(df),
    "Normality Test":analyzeNormality(df),
    "Outlier Summary":detectOutliers(df),"Correlation Matrix":correlationAnalysis(df),
    "Highly Correlated Features":highCorrFeatures(df)}
    if target is not None:
        summary["Class Distribution"]=classDistribution(df,target)
        summary["Mutual Information"]=mi
    print('----- EDA Summary -----')
    for k,v in summary.items():
        print(f'{k}:')
        print(v)
        print()
    print('----- Generating Plots -----')
    if full:
        generateAllPlots(df,target,n,midf=mi)
    else:
        generateCorePlots(df,target,n,midf=mi)
    return summary

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.impute import SimpleImputer

def preprocessData(df,tgt,dc=None):
    df=df.copy()
    df.columns=df.columns.str.strip()
    tgt=tgt.strip()
    if dc:
        df=df.drop(columns=[c for c in dc if c in df.columns])
    df=df.dropna(subset=[tgt])
    miss,dup,single,empty,mixed=checkMissing(df)
    df=df.drop(columns=list(set(empty+single)),errors='ignore')
    df=df.drop_duplicates()
    nc=df.select_dtypes(include='number').columns.tolist()
    cc=df.select_dtypes(include=['object','string','category']).columns.tolist()
    if tgt in nc:nc.remove(tgt)
    if tgt in cc:cc.remove(tgt)
    if nc:df[nc]=SimpleImputer(strategy='median').fit_transform(df[nc])
    if cc:
        df[cc]=SimpleImputer(strategy='most_frequent').fit_transform(df[cc])
        for c in cc:df[c]=LabelEncoder().fit_transform(df[c].astype(str))
    enc=None
    if df[tgt].dtype=='object' or str(df[tgt].dtype)=='category':
        enc=LabelEncoder()
        df[tgt]=enc.fit_transform(df[tgt].astype(str))
    if nc:df[nc]=StandardScaler().fit_transform(df[nc])
    return df,enc

# %%
from sklearn.feature_selection import SelectKBest,chi2,f_classif,f_regression

def selectFeatures(X,y,task,k=10):
    k=min(k,X.shape[1])
    if task=='classification':
        try:
            Xpos=X-X.min()+1e-6
            sel=SelectKBest(chi2,k=k).fit(Xpos,y)
            mtd='Chi-Square'
        except Exception:
            sel=SelectKBest(f_classif,k=k).fit(X,y)
            mtd='ANOVA (f_classif)'
    else:
        sel=SelectKBest(f_regression,k=k).fit(X,y)
        mtd='ANOVA (f_regression)'
    sc=pd.DataFrame({'Feature':X.columns,'Score':sel.scores_}).sort_values('Score',ascending=False)
    feats=X.columns[sel.get_support()].tolist()
    return feats,sc,mtd

# %%
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report,mean_absolute_error,mean_squared_error,r2_score

def getModel(task):
    return RandomForestClassifier(random_state=42) if task=='classification' else RandomForestRegressor(random_state=42)

def evaluateModel(mdl,X,y,task,label=''):
    yp=mdl.predict(X)
    print(f'--- {label} ---')
    if task=='classification':
        print('Accuracy :',accuracy_score(y,yp))
        print('Precision:',precision_score(y,yp,average='weighted',zero_division=0))
        print('Recall   :',recall_score(y,yp,average='weighted',zero_division=0))
        print('F1       :',f1_score(y,yp,average='weighted',zero_division=0))
        print(classification_report(y,yp,zero_division=0))
        setGraphStyle()
        fig,ax=plt.subplots(figsize=singlesize)
        sns.heatmap(confusion_matrix(y,yp),annot=True,fmt='d',cmap='Blues',ax=ax)
        ax.set_xlabel('Predicted');ax.set_ylabel('Actual');ax.set_title(f'Confusion Matrix - {label}')
        showFig(fig)
    else:
        mae,mse=mean_absolute_error(y,yp),mean_squared_error(y,yp)
        print(f'MAE:{mae:.4f} MSE:{mse:.4f} RMSE:{np.sqrt(mse):.4f} R2:{r2_score(y,yp):.4f}')
        setGraphStyle()
        fig,ax=plt.subplots(figsize=singlesize)
        ax.scatter(y,yp,alpha=0.6,color='#4C72B0')
        ax.set_xlabel('Actual');ax.set_ylabel('Predicted');ax.set_title(f'Actual vs Predicted - {label}')
        showFig(fig)

# %%
from sklearn.model_selection import train_test_split

def runPipeline(path,tgt,task,dc=None,k=10,ts=0.2,vs=0.1):
    df=pd.read_csv(path)
    print(f'Loaded {path} | shape={df.shape}')
    dfp,enc=preprocessData(df,tgt,dc)
    edaSummary(dfp,target=tgt,full=False)
    X,y=dfp.drop(columns=[tgt]),dfp[tgt]
    feats,sc,mtd=selectFeatures(X,y,task,k=k)
    print(f'Feature Selection ({mtd}):');print(sc)
    X=X[feats]
    Xtr,Xtmp,ytr,ytmp=train_test_split(X,y,test_size=ts+vs,random_state=42)
    Xval,Xte,yval,yte=train_test_split(Xtmp,ytmp,test_size=ts/(ts+vs),random_state=42)
    print(f'Train:{Xtr.shape} Val:{Xval.shape} Test:{Xte.shape}')
    mdl=getModel(task).fit(Xtr,ytr)
    evaluateModel(mdl,Xval,yval,task,'Validation')
    evaluateModel(mdl,Xte,yte,task,'Test')
    return {'model':mdl,'feats':feats,'mtd':mtd}

# %%
res_iris=runPipeline(path='iris/Iris.csv',tgt='Species',task='classification',k=4)
# Out:
# Loaded iris/Iris.csv | shape=(150, 6)
# ----- EDA Summary -----
# Rows:
# 150
#
# Columns:
# 6
#
# Column Names:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
#
# Data Types:
# ['float64', 'float64', 'float64', 'float64', 'float64', 'int64']
#
# Missing Values:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Single Value Columns:
# []
#
# Empty Columns:
# []
#
# Mixed Type Columns:
# []
#
# Numerical Summary:
#                        Mean    Median      Mode       Std       Min       Max  \
# Id             0.000000e+00  0.000000 -1.720542  1.003350 -1.720542  1.720542
# SepalLengthCm -4.736952e-16 -0.052506 -1.021849  1.003350 -1.870024  2.492019
# SepalWidthCm  -6.631732e-16 -0.124958 -0.124958  1.003350 -2.438987  3.114684
# PetalLengthCm  3.315866e-16  0.336266 -1.284407  1.003350 -1.568735  1.786341
# PetalWidthCm  -2.842171e-16  0.133226 -1.312977  1.003350 -1.444450  1.710902
# Species        1.000000e+00  1.000000  0.000000  0.819232  0.000000  2.000000
#
#                      Q1        Q3     Range      Skewness  Kurtosis
# Id            -0.860271  0.860271  3.441084  9.569869e-17 -1.200000
# SepalLengthCm -0.900681  0.674501  4.362043  3.149110e-01 -0.552064
# SepalWidthCm  -0.587764  0.569251  5.553671  3.340527e-01  0.290781
# PetalLengthCm -1.227541  0.762759  3.355077 -2.744643e-01 -1.401921
# PetalWidthCm  -1.181504  0.790591  3.155351 -1.049966e-01 -1.339754
# Species        0.000000  2.000000  2.000000  0.000000e+00 -1.510135
#
# Categorical Summary:
# None
#
# Normality Test:
#           Column  Statistic       P-Value      Result
# 0             Id   0.954616  8.080962e-05  Not Normal
# 1  SepalLengthCm   0.976090  1.018116e-02  Not Normal
# 2   SepalWidthCm   0.983792  7.517919e-02      Normal
# 3  PetalLengthCm   0.876425  7.545420e-10  Not Normal
# 4   PetalWidthCm   0.902625  1.864760e-08  Not Normal
# 5        Species   0.792897  2.716318e-13  Not Normal
#
# Outlier Summary:
#           Column  Outlier Count
# 0             Id              0
# 1  SepalLengthCm              0
# 2   SepalWidthCm              4
# 3  PetalLengthCm              0
# 4   PetalWidthCm              0
# 5        Species              0
#
# Correlation Matrix:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species        0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm   Species
# Id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# Species            0.956464  1.000000
#
# Highly Correlated Features:
#         Feature1       Feature2  Correlation
# 0             Id  PetalLengthCm     0.882747
# 1             Id   PetalWidthCm     0.899759
# 2             Id        Species     0.942830
# 3  SepalLengthCm  PetalLengthCm     0.871754
# 4  SepalLengthCm   PetalWidthCm     0.817954
# 5  PetalLengthCm   PetalWidthCm     0.962757
# 6  PetalLengthCm        Species     0.949043
# 7   PetalWidthCm        Species     0.956464
#
# Class Distribution:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64
#
# Mutual Information:
#          Feature  Mutual Information
# 0             Id            1.081309
# 1  PetalLengthCm            0.999832
# 2   PetalWidthCm            0.985305
# 3  SepalLengthCm            0.498548
# 4   SepalWidthCm            0.201910
#
# ----- Generating Plots -----
# Feature Selection (Chi-Square):
#          Feature      Score
# 4   PetalWidthCm  96.455620
# 3  PetalLengthCm  90.007386
# 0             Id  77.498358
# 1  SepalLengthCm  49.628135
# 2   SepalWidthCm  24.101026
# Train:(104, 4) Val:(15, 4) Test:(31, 4)
# --- Validation ---
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1       : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
# --- Test ---
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1       : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        31
#    macro avg       1.00      1.00      1.00        31
# weighted avg       1.00      1.00      1.00        31

# %%
res_loan=runPipeline(path='loan/train.csv',tgt='Loan Sanction Amount (USD)',task='regression',dc=['Loan_ID'],k=8)
# Out:
# Loaded loan/train.csv | shape=(30000, 24)
# ----- EDA Summary -----
# Rows:
# 29660
#
# Columns:
# 24
#
# Column Names:
# ['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)', 'Income Stability', 'Profession', 'Type of Employment', 'Location', 'Loan Amount Request (USD)', 'Current Loan Expenses (USD)', 'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score', 'No. of Defaults', 'Has Active Credit Card', 'Property ID', 'Property Age', 'Property Type', 'Property Location', 'Co-Applicant', 'Property Price', 'Loan Sanction Amount (USD)']
#
# Data Types:
# ['int64', 'int64', 'int64', 'float64', 'float64', 'int64', 'int64', 'int64', 'int64', 'float64', 'float64', 'int64', 'int64', 'float64', 'float64', 'float64', 'int64', 'float64', 'float64', 'float64', 'int64', 'float64', 'float64', 'float64']
#
# Missing Values:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Single Value Columns:
# []
#
# Empty Columns:
# []
#
# Mixed Type Columns:
# []
#
# Numerical Summary:
#                                      Mean        Median      Mode  \
# Customer ID                  1.482950e+04  14829.500000  0.000000
# Name                         1.482950e+04  14829.500000  0.000000
# Gender                       5.037761e-01      1.000000  1.000000
# Age                         -1.926083e-16     -0.006182 -1.376920
# Income (USD)                -1.988370e-17     -0.033176 -0.033176
# Income Stability             9.142279e-01      1.000000  1.000000
# Profession                   4.805968e+00      7.000000  7.000000
# Type of Employment           7.892717e+00      8.000000  8.000000
# Location                     9.252529e-01      1.000000  1.000000
# Loan Amount Request (USD)   -2.630398e-16     -0.229959 -1.151123
# Current Loan Expenses (USD)  2.414791e-16     -0.106208 -5.793996
# Expense Type 1               3.599461e-01      0.000000  0.000000
# Expense Type 2               6.725893e-01      1.000000  1.000000
# Dependents                   2.874751e-18     -0.254230 -0.254230
# Credit Score                 5.278762e-16     -0.000518 -0.000518
# No. of Defaults             -2.970577e-17     -0.490710 -0.490710
# Has Active Credit Card       9.282535e-01      1.000000  0.000000
# Property ID                 -2.395626e-17      0.007351  1.169916
# Property Age                 1.509245e-17     -0.032800 -0.032800
# Property Type                1.748807e-16     -0.411213 -1.305127
# Property Location            9.730276e-01      1.000000  1.000000
# Co-Applicant                -3.677286e-17      0.076750  0.076750
# Property Price              -8.791948e-17     -0.232712 -1.420819
# Loan Sanction Amount (USD)   4.764934e+04  35209.395000  0.000000
#
#                                       Std         Min            Max  \
# Customer ID                   8562.248828    0.000000   29659.000000
# Name                          8562.248828    0.000000   29659.000000
# Gender                           0.499994    0.000000       1.000000
# Age                              1.000017   -1.376920       1.551474
# Income (USD)                     1.000017   -0.210172     170.215356
# Income Stability                 0.280032    0.000000       1.000000
# Profession                       2.628500    0.000000       7.000000
# Type of Employment               3.892988    0.000000      17.000000
# Location                         0.525081    0.000000       2.000000
# Loan Amount Request (USD)        1.000017   -1.391120       8.956050
# Current Loan Expenses (USD)      1.000017   -5.793996      14.239779
# Expense Type 1                   0.479992    0.000000       1.000000
# Expense Type 2                   0.469276    0.000000       1.000000
# Dependents                       1.000017   -1.347686      12.867243
# Credit Score                     1.000017   -2.280652       2.231535
# No. of Defaults                  1.000017   -0.490710       2.037863
# Has Active Credit Card           0.824196    0.000000       2.000000
# Property ID                      1.000017   -1.738232       1.725171
# Property Age                     1.000017   -0.209878     170.233300
# Property Type                    1.000017   -1.305127       1.376616
# Property Location                0.801151    0.000000       2.000000
# Co-Applicant                     1.000017  -13.369876       0.076750
# Property Price                   1.000017   -1.420819      10.128839
# Loan Sanction Amount (USD)   48221.146686 -999.000000  481907.320000
#
#                                       Q1            Q3          Range  \
# Customer ID                  7414.750000  22244.250000   29659.000000
# Name                         7414.750000  22244.250000   29659.000000
# Gender                          0.000000      1.000000       1.000000
# Age                            -0.940776      0.928412       2.928394
# Income (USD)                   -0.079302      0.028827     170.425528
# Income Stability                1.000000      1.000000       1.000000
# Profession                      1.000000      7.000000       7.000000
# Type of Employment              6.000000     10.000000      17.000000
# Location                        1.000000      1.000000       2.000000
# Loan Amount Request (USD)      -0.800134      0.522845      10.347170
# Current Loan Expenses (USD)    -0.629304      0.493630      20.033775
# Expense Type 1                  0.000000      1.000000       1.000000
# Expense Type 2                  0.000000      1.000000       1.000000
# Dependents                     -0.254230      0.839226      14.214929
# Credit Score                   -0.778052      0.788537       4.512186
# No. of Defaults                -0.490710     -0.490710       2.528573
# Has Active Credit Card          0.000000      2.000000       2.000000
# Property ID                    -0.870646      0.864526       3.463403
# Property Age                   -0.078363      0.027306     170.443178
# Property Type                  -1.305127      0.482702       2.681742
# Property Location               0.000000      2.000000       2.000000
# Co-Applicant                    0.076750      0.076750      13.446626
# Property Price                 -0.760811      0.503838      11.549658
# Loan Sanction Amount (USD)      0.000000  74261.250000  482906.320000
#
#                                Skewness      Kurtosis
# Customer ID                    0.000000     -1.200000
# Name                           0.000000     -1.200000
# Gender                        -0.015106     -1.999907
# Age                            0.046153     -1.382450
# Income (USD)                 166.351330  28304.855123
# Income Stability              -2.958633      6.753965
# Profession                    -0.509072     -1.538752
# Type of Employment             0.015414     -0.317749
# Location                      -0.086394      0.529722
# Loan Amount Request (USD)      1.260674      2.107165
# Current Loan Expenses (USD)    0.054663     10.888772
# Expense Type 1                 0.583607     -1.659515
# Expense Type 2                -0.735605     -1.458984
# Dependents                     0.901483      1.827233
# Credit Score                  -0.020760     -0.865766
# No. of Defaults                1.547231      0.393949
# Has Active Credit Card         0.133668     -1.515725
# Property ID                   -0.011087     -1.203134
# Property Age                 166.403884  28316.793878
# Property Type                  0.051083     -1.359307
# Property Location              0.048587     -1.440468
# Co-Applicant                 -13.295453    174.784886
# Property Price                 1.416816      3.156676
# Loan Sanction Amount (USD)     1.229939      1.760122
#
# Categorical Summary:
# None
#
# Normality Test:
#                          Column  Statistic       P-Value      Result
# 0                   Customer ID   0.954802  8.717172e-37  Not Normal
# 1                          Name   0.956028  2.173342e-36  Not Normal
# 2                        Gender   0.636623  2.120636e-73  Not Normal
# 3                           Age   0.916813  3.657926e-46  Not Normal
# 4                  Income (USD)   0.759896  4.321824e-65  Not Normal
# 5              Income Stability   0.304276  1.870756e-87  Not Normal
# 6                    Profession   0.703032  2.737121e-69  Not Normal
# 7            Type of Employment   0.924404  1.280508e-44  Not Normal
# 8                      Location   0.699299  1.536088e-69  Not Normal
# 9     Loan Amount Request (USD)   0.903820  1.476828e-48  Not Normal
# 10  Current Loan Expenses (USD)   0.877314  1.032151e-52  Not Normal
# 11               Expense Type 1   0.610463  7.626141e-75  Not Normal
# 12               Expense Type 2   0.587480  4.792455e-76  Not Normal
# 13                   Dependents   0.846915  1.205752e-56  Not Normal
# 14                 Credit Score   0.982762  3.189737e-24  Not Normal
# 15              No. of Defaults   0.486946  1.045014e-80  Not Normal
# 16       Has Active Credit Card   0.786786  8.376848e-63  Not Normal
# 17                  Property ID   0.951766  9.859475e-38  Not Normal
# 18                 Property Age   0.758817  3.535740e-65  Not Normal
# 19                Property Type   0.850574  3.296564e-56  Not Normal
# 20            Property Location   0.800037  1.384356e-61  Not Normal
# 21                 Co-Applicant   0.037944  6.137576e-95  Not Normal
# 22               Property Price   0.894917  4.768129e-50  Not Normal
# 23   Loan Sanction Amount (USD)   0.877952  1.272479e-52  Not Normal
#
# Outlier Summary:
#                          Column  Outlier Count
# 0                   Customer ID              0
# 1                          Name              0
# 2                        Gender              0
# 3                           Age              0
# 4                  Income (USD)           1850
# 5              Income Stability           2544
# 6                    Profession              0
# 7            Type of Employment            148
# 8                      Location           8343
# 9     Loan Amount Request (USD)            748
# 10  Current Loan Expenses (USD)            864
# 11               Expense Type 1              0
# 12               Expense Type 2              0
# 13                   Dependents            430
# 14                 Credit Score              0
# 15              No. of Defaults           5756
# 16       Has Active Credit Card              0
# 17                  Property ID              0
# 18                 Property Age           1901
# 19                Property Type              0
# 20            Property Location              0
# 21                 Co-Applicant           4458
# 22               Property Price            852
# 23   Loan Sanction Amount (USD)            438
#
# Correlation Matrix:
#                              Customer ID      Name    Gender       Age  \
# Customer ID                     1.000000 -0.004623  0.003890  0.003140
# Name                           -0.004623  1.000000  0.000394 -0.001424
# Gender                          0.003890  0.000394  1.000000  0.004216
# Age                             0.003140 -0.001424  0.004216  1.000000
# Income (USD)                    0.005868 -0.002668  0.005490 -0.009410
# Income Stability               -0.005395 -0.005306 -0.005393 -0.446093
# Profession                      0.002929 -0.004405 -0.002713 -0.093523
# Type of Employment             -0.001858  0.004164 -0.004209 -0.001283
# Location                       -0.000346 -0.006159  0.002552 -0.016955
# Loan Amount Request (USD)       0.002368 -0.003620  0.000269 -0.010366
# Current Loan Expenses (USD)     0.016634 -0.009114 -0.007974 -0.023481
# Expense Type 1                  0.005084 -0.001787 -0.001028 -0.045093
# Expense Type 2                  0.004587 -0.007557  0.003329  0.029883
# Dependents                      0.019763 -0.005601 -0.006197 -0.079691
# Credit Score                   -0.000928 -0.000799  0.000522  0.126956
# No. of Defaults                -0.005428 -0.003764  0.000557  0.003452
# Has Active Credit Card         -0.012523 -0.005061  0.009003  0.008116
# Property ID                     0.004270 -0.006621 -0.003008 -0.012820
# Property Age                    0.006080 -0.002632  0.005403 -0.009505
# Property Type                   0.012025  0.000854  0.003284  0.001463
# Property Location               0.006106  0.005210 -0.003449  0.003819
# Co-Applicant                    0.039892 -0.003765  0.000136  0.001577
# Property Price                  0.005162 -0.000347 -0.002196 -0.010132
# Loan Sanction Amount (USD)     -0.186605 -0.000213 -0.002346  0.008112
#
#                              Income (USD)  Income Stability  Profession  \
# Customer ID                      0.005868         -0.005395    0.002929
# Name                            -0.002668         -0.005306   -0.004405
# Gender                           0.005490         -0.005393   -0.002713
# Age                             -0.009410         -0.446093   -0.093523
# Income (USD)                     1.000000          0.012065   -0.012347
# Income Stability                 0.012065          1.000000    0.210178
# Profession                      -0.012347          0.210178    1.000000
# Type of Employment              -0.001535         -0.008441    0.002766
# Location                         0.026082          0.019913   -0.144283
# Loan Amount Request (USD)        0.045779          0.014300   -0.084859
# Current Loan Expenses (USD)      0.050385          0.040655   -0.081384
# Expense Type 1                   0.018989          0.097252    0.005278
# Expense Type 2                   0.004682         -0.049244   -0.013920
# Dependents                       0.004971          0.156072    0.065656
# Credit Score                     0.011610         -0.273488   -0.142220
# No. of Defaults                 -0.002038         -0.003743    0.005931
# Has Active Credit Card          -0.001840         -0.013224    0.019923
# Property ID                     -0.007456         -0.005341   -0.000197
# Property Age                     0.999886          0.011995   -0.012137
# Property Type                    0.008905         -0.008365    0.003238
# Property Location               -0.000045         -0.007006   -0.008409
# Co-Applicant                     0.000714         -0.005608   -0.009092
# Property Price                   0.046212          0.012172   -0.083908
# Loan Sanction Amount (USD)       0.033811         -0.040761   -0.092890
#
#                              Type of Employment  Location  \
# Customer ID                           -0.001858 -0.000346
# Name                                   0.004164 -0.006159
# Gender                                -0.004209  0.002552
# Age                                   -0.001283 -0.016955
# Income (USD)                          -0.001535  0.026082
# Income Stability                      -0.008441  0.019913
# Profession                             0.002766 -0.144283
# Type of Employment                     1.000000 -0.013358
# Location                              -0.013358  1.000000
# Loan Amount Request (USD)             -0.031309  0.104263
# Current Loan Expenses (USD)           -0.012640  0.121579
# Expense Type 1                        -0.034150  0.022073
# Expense Type 2                         0.009582  0.003576
# Dependents                            -0.023497 -0.030019
# Credit Score                          -0.062056  0.130359
# No. of Defaults                       -0.005113 -0.011813
# Has Active Credit Card                 0.000543 -0.015041
# Property ID                            0.007503  0.001561
# Property Age                          -0.001591  0.025651
# Property Type                         -0.014549 -0.003395
# Property Location                     -0.001663 -0.001026
# Co-Applicant                           0.000771  0.004071
# Property Price                        -0.029605  0.100605
# Loan Sanction Amount (USD)            -0.030357  0.101299
#
#                              Loan Amount Request (USD)  ...  Credit Score  \
# Customer ID                                   0.002368  ...     -0.000928
# Name                                         -0.003620  ...     -0.000799
# Gender                                        0.000269  ...      0.000522
# Age                                          -0.010366  ...      0.126956
# Income (USD)                                  0.045779  ...      0.011610
# Income Stability                              0.014300  ...     -0.273488
# Profession                                   -0.084859  ...     -0.142220
# Type of Employment                           -0.031309  ...     -0.062056
# Location                                      0.104263  ...      0.130359
# Loan Amount Request (USD)                     1.000000  ...      0.172443
# Current Loan Expenses (USD)                   0.681181  ...      0.110927
# Expense Type 1                                0.096446  ...     -0.047061
# Expense Type 2                               -0.023976  ...      0.073831
# Dependents                                    0.039133  ...     -0.083323
# Credit Score                                  0.172443  ...      1.000000
# No. of Defaults                              -0.000114  ...      0.006857
# Has Active Credit Card                       -0.026150  ...      0.007816
# Property ID                                  -0.009390  ...     -0.006426
# Property Age                                  0.045228  ...      0.011563
# Property Type                                 0.004043  ...      0.008031
# Property Location                             0.006047  ...      0.003402
# Co-Applicant                                  0.002188  ...      0.009849
# Property Price                                0.948553  ...      0.165145
# Loan Sanction Amount (USD)                    0.726408  ...      0.359701
#
#                              No. of Defaults  Has Active Credit Card  \
# Customer ID                        -0.005428               -0.012523
# Name                               -0.003764               -0.005061
# Gender                              0.000557                0.009003
# Age                                 0.003452                0.008116
# Income (USD)                       -0.002038               -0.001840
# Income Stability                   -0.003743               -0.013224
# Profession                          0.005931                0.019923
# Type of Employment                 -0.005113                0.000543
# Location                           -0.011813               -0.015041
# Loan Amount Request (USD)          -0.000114               -0.026150
# Current Loan Expenses (USD)         0.001929               -0.003673
# Expense Type 1                      0.006421               -0.009378
# Expense Type 2                      0.001376                0.030273
# Dependents                          0.007991                0.014393
# Credit Score                        0.006857                0.007816
# No. of Defaults                     1.000000               -0.003106
# Has Active Credit Card             -0.003106                1.000000
# Property ID                        -0.001879                0.008183
# Property Age                       -0.001973               -0.001934
# Property Type                       0.000089                0.008810
# Property Location                   0.004816               -0.002676
# Co-Applicant                       -0.007805                0.001704
# Property Price                      0.001622               -0.025072
# Loan Sanction Amount (USD)         -0.004330               -0.013815
#
#                              Property ID  Property Age  Property Type  \
# Customer ID                     0.004270      0.006080       0.012025
# Name                           -0.006621     -0.002632       0.000854
# Gender                         -0.003008      0.005403       0.003284
# Age                            -0.012820     -0.009505       0.001463
# Income (USD)                   -0.007456      0.999886       0.008905
# Income Stability               -0.005341      0.011995      -0.008365
# Profession                     -0.000197     -0.012137       0.003238
# Type of Employment              0.007503     -0.001591      -0.014549
# Location                        0.001561      0.025651      -0.003395
# Loan Amount Request (USD)      -0.009390      0.045228       0.004043
# Current Loan Expenses (USD)    -0.015991      0.049751       0.015195
# Expense Type 1                 -0.000230      0.018624       0.009663
# Expense Type 2                 -0.003087      0.004630       0.006114
# Dependents                      0.002433      0.004861      -0.008972
# Credit Score                   -0.006426      0.011563       0.008031
# No. of Defaults                -0.001879     -0.001973       0.000089
# Has Active Credit Card          0.008183     -0.001934       0.008810
# Property ID                     1.000000     -0.007356       0.008987
# Property Age                   -0.007356      1.000000       0.008896
# Property Type                   0.008987      0.008896       1.000000
# Property Location              -0.028764     -0.000025      -0.029870
# Co-Applicant                    0.009389      0.000689      -0.000466
# Property Price                 -0.012369      0.045679       0.003138
# Loan Sanction Amount (USD)     -0.009751      0.033251       0.001984
#
#                              Property Location  Co-Applicant  Property Price  \
# Customer ID                           0.006106      0.039892        0.005162
# Name                                  0.005210     -0.003765       -0.000347
# Gender                               -0.003449      0.000136       -0.002196
# Age                                   0.003819      0.001577       -0.010132
# Income (USD)                         -0.000045      0.000714        0.046212
# Income Stability                     -0.007006     -0.005608        0.012172
# Profession                           -0.008409     -0.009092       -0.083908
# Type of Employment                   -0.001663      0.000771       -0.029605
# Location                             -0.001026      0.004071        0.100605
# Loan Amount Request (USD)             0.006047      0.002188        0.948553
# Current Loan Expenses (USD)          -0.001268      0.002467        0.647944
# Expense Type 1                        0.000172     -0.005207        0.091592
# Expense Type 2                       -0.017302     -0.001961       -0.025007
# Dependents                           -0.002209      0.003844        0.035927
# Credit Score                          0.003402      0.009849        0.165145
# No. of Defaults                       0.004816     -0.007805        0.001622
# Has Active Credit Card               -0.002676      0.001704       -0.025072
# Property ID                          -0.028764      0.009389       -0.012369
# Property Age                         -0.000025      0.000689        0.045679
# Property Type                        -0.029870     -0.000466        0.003138
# Property Location                     1.000000     -0.003641        0.004154
# Co-Applicant                         -0.003641      1.000000        0.006240
# Property Price                        0.004154      0.006240        1.000000
# Loan Sanction Amount (USD)            0.007244     -0.006945        0.687181
#
#                              Loan Sanction Amount (USD)
# Customer ID                                   -0.186605
# Name                                          -0.000213
# Gender                                        -0.002346
# Age                                            0.008112
# Income (USD)                                   0.033811
# Income Stability                              -0.040761
# Profession                                    -0.092890
# Type of Employment                            -0.030357
# Location                                       0.101299
# Loan Amount Request (USD)                      0.726408
# Current Loan Expenses (USD)                    0.483610
# Expense Type 1                                 0.055430
# Expense Type 2                                 0.008712
# Dependents                                     0.004788
# Credit Score                                   0.359701
# No. of Defaults                               -0.004330
# Has Active Credit Card                        -0.013815
# Property ID                                   -0.009751
# Property Age                                   0.033251
# Property Type                                  0.001984
# Property Location                              0.007244
# Co-Applicant                                  -0.006945
# Property Price                                 0.687181
# Loan Sanction Amount (USD)                     1.000000
#
# [24 rows x 24 columns]
#
# Highly Correlated Features:
#                     Feature1        Feature2  Correlation
# 0               Income (USD)    Property Age     0.999886
# 1  Loan Amount Request (USD)  Property Price     0.948553
#
# Class Distribution:
# Loan Sanction Amount (USD)
#  0.00         7865
# -999.00        338
#  28937.45        3
#  27394.93        2
#  26047.92        2
#               ...
#  164339.54       1
#  24156.78        1
#  60149.10        1
#  14002.40        1
#  56040.54        1
# Name: count, Length: 21450, dtype: int64
#
# Mutual Information:
#                         Feature  Mutual Information
# 0     Loan Amount Request (USD)            4.430223
# 1                Property Price            1.052868
# 2   Current Loan Expenses (USD)            0.492658
# 3                   Customer ID            0.202609
# 4                  Credit Score            0.199765
# 5                  Co-Applicant            0.090735
# 6                  Income (USD)            0.074885
# 7                  Property Age            0.073098
# 8                      Location            0.010912
# 9                    Profession            0.010145
# 10           Type of Employment            0.007618
# 11                   Dependents            0.005001
# 12                       Gender            0.003718
# 13             Income Stability            0.002884
# 14                  Property ID            0.002734
# 15               Expense Type 1            0.002260
# 16                Property Type            0.001434
# 17       Has Active Credit Card            0.000832
# 18               Expense Type 2            0.000115
# 19                          Age            0.000000
# 20                         Name            0.000000
# 21              No. of Defaults            0.000000
# 22            Property Location            0.000000
#
# ----- Generating Plots -----
# plotTargetOverview: target has 21450 unique values, treating as continuous - showing distribution histogram instead of class bars
# Feature Selection (ANOVA (f_regression)):
#                         Feature         Score
# 9     Loan Amount Request (USD)  33132.613503
# 22               Property Price  26535.644453
# 10  Current Loan Expenses (USD)   9053.878707
# 14                 Credit Score   4407.562495
# 0                   Customer ID   1069.993492
# 8                      Location    307.493149
# 6                    Profession    258.132624
# 11               Expense Type 1     91.405648
# 5              Income Stability     49.356861
# 4                  Income (USD)     33.943493
# 18                 Property Age     32.826919
# 7            Type of Employment     27.356249
# 16       Has Active Credit Card      5.661805
# 17                  Property ID      2.820414
# 12               Expense Type 2      2.251370
# 3                           Age      1.951998
# 20            Property Location      1.556518
# 21                 Co-Applicant      1.430482
# 13                   Dependents      0.679789
# 15              No. of Defaults      0.556013
# 2                        Gender      0.163249
# 19                Property Type      0.116770
# 1                          Name      0.001350
# Train:(20761, 8) Val:(2966, 8) Test:(5933, 8)
# --- Validation ---
# MAE:5591.3631 MSE:197804677.2386 RMSE:14064.3051 R2:0.9070
# --- Test ---
# MAE:5964.6129 MSE:254135872.9770 RMSE:15941.6396 R2:0.8918

# %%
res_diab=runPipeline(path='diabetes/diabetes.csv',tgt='Outcome',task='classification',k=6)
# Out:
# Loaded diabetes/diabetes.csv | shape=(768, 9)
# ----- EDA Summary -----
# Rows:
# 768
#
# Columns:
# 9
#
# Column Names:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
#
# Data Types:
# ['float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'int64']
#
# Missing Values:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Single Value Columns:
# []
#
# Empty Columns:
# []
#
# Mixed Type Columns:
# []
#
# Numerical Summary:
#                                   Mean    Median      Mode       Std  \
# Pregnancies              -6.476301e-17 -0.250952 -0.844885  1.000652
# Glucose                  -9.251859e-18 -0.121888 -0.685236  1.000652
# BloodPressure             1.503427e-17  0.149641  0.046245  1.000652
# SkinThickness             1.006140e-16  0.154533 -1.288212  1.000652
# Insulin                  -3.006854e-17 -0.428062 -0.692891  1.000652
# BMI                       2.590520e-16  0.000942  0.000942  1.000652
# DiabetesPedigreeFunction  2.451743e-16 -0.300128 -0.658012  1.000652
# Age                       1.931325e-16 -0.360847 -0.956462  1.000652
# Outcome                   3.489583e-01  0.000000  0.000000  0.476951
#
#                                Min       Max        Q1        Q3     Range  \
# Pregnancies              -1.141852  3.906578 -0.844885  0.639947  5.048430
# Glucose                  -3.783654  2.444478 -0.685236  0.605771  6.228132
# BloodPressure            -3.572597  2.734528 -0.367337  0.563223  6.307125
# SkinThickness            -1.288212  4.921866 -1.288212  0.719086  6.210078
# Insulin                  -0.692891  6.652839 -0.692891  0.412008  7.345730
# BMI                      -4.060474  4.455807 -0.595578  0.584771  8.516281
# DiabetesPedigreeFunction -1.189553  5.883565 -0.688969  0.466227  7.073118
# Age                      -1.041549  4.063716 -0.786286  0.660206  5.105265
# Outcome                   0.000000  1.000000  0.000000  1.000000  1.000000
#
#                           Skewness  Kurtosis
# Pregnancies               0.901674  0.159220
# Glucose                   0.173754  0.640780
# BloodPressure            -1.843608  5.180157
# SkinThickness             0.109372 -0.520072
# Insulin                   2.272251  7.214260
# BMI                      -0.428982  3.290443
# DiabetesPedigreeFunction  1.919911  5.594954
# Age                       1.129597  0.643159
# Outcome                   0.635017 -1.600930
#
# Categorical Summary:
# None
#
# Normality Test:
#                      Column  Statistic       P-Value      Result
# 0               Pregnancies   0.904281  1.609257e-21  Not Normal
# 1                   Glucose   0.970104  1.986347e-11  Not Normal
# 2             BloodPressure   0.818922  1.584162e-28  Not Normal
# 3             SkinThickness   0.904628  1.751754e-21  Not Normal
# 4                   Insulin   0.722020  7.914332e-34  Not Normal
# 5                       BMI   0.949990  1.841652e-15  Not Normal
# 6  DiabetesPedigreeFunction   0.836518  2.477506e-27  Not Normal
# 7                       Age   0.874767  2.402274e-24  Not Normal
# 8                   Outcome   0.602514  1.292690e-38  Not Normal
#
# Outlier Summary:
#                      Column  Outlier Count
# 0               Pregnancies              4
# 1                   Glucose              5
# 2             BloodPressure             45
# 3             SkinThickness              1
# 4                   Insulin             34
# 5                       BMI             19
# 6  DiabetesPedigreeFunction             29
# 7                       Age              9
# 8                   Outcome              0
#
# Correlation Matrix:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000
#
# Highly Correlated Features:
# Empty DataFrame
# Columns: [Feature1, Feature2, Correlation]
# Index: []
#
# Class Distribution:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
#
# Mutual Information:
#                     Feature  Mutual Information
# 0                   Glucose            0.114634
# 1                       BMI            0.080061
# 2               Pregnancies            0.061636
# 3                       Age            0.051395
# 4  DiabetesPedigreeFunction            0.014590
# 5                   Insulin            0.011948
# 6             SkinThickness            0.004667
# 7             BloodPressure            0.000000
#
# ----- Generating Plots -----
# Feature Selection (Chi-Square):
#                     Feature      Score
# 1                   Glucose  44.188022
# 7                       Age  41.892187
# 0               Pregnancies  33.117579
# 6  DiabetesPedigreeFunction  19.511773
# 4                   Insulin  18.890180
# 5                       BMI  16.203693
# 3             SkinThickness   3.331362
# 2             BloodPressure   0.910158
# Train:(537, 6) Val:(77, 6) Test:(154, 6)
# --- Validation ---
# Accuracy : 0.7402597402597403
# Precision: 0.7530974772354083
# Recall   : 0.7402597402597403
# F1       : 0.7446849446849447
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        52
#            1       0.59      0.68      0.63        25
#
#     accuracy                           0.74        77
#    macro avg       0.71      0.72      0.71        77
# weighted avg       0.75      0.74      0.74        77
# --- Test ---
# Accuracy : 0.7597402597402597
# Precision: 0.7607507288629737
# Recall   : 0.7597402597402597
# F1       : 0.7602127145274353
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81        99
#            1       0.66      0.67      0.67        55
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.74      0.74       154
# weighted avg       0.76      0.76      0.76       154

# %%
res_spam=runPipeline(path='spam/spambase.csv',tgt='spam',task='classification',k=10)
# Out:
# Loaded spam/spambase.csv | shape=(4601, 58)
# ----- EDA Summary -----
# Rows:
# 4210
#
# Columns:
# 58
#
# Column Names:
# ['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d', 'word_freq_our', 'word_freq_over', 'word_freq_remove', 'word_freq_internet', 'word_freq_order', 'word_freq_mail', 'word_freq_receive', 'word_freq_will', 'word_freq_people', 'word_freq_report', 'word_freq_addresses', 'word_freq_free', 'word_freq_business', 'word_freq_email', 'word_freq_you', 'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000', 'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george', 'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet', 'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85', 'word_freq_technology', 'word_freq_1999', 'word_freq_parts', 'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting', 'word_freq_original', 'word_freq_project', 'word_freq_re', 'word_freq_edu', 'word_freq_table', 'word_freq_conference', 'char_freq_;', 'char_freq_(', 'char_freq_[', 'char_freq_!', 'char_freq_$', 'char_freq_#', 'capital_run_length_average', 'capital_run_length_longest', 'capital_run_length_total', 'spam']
#
# Data Types:
# ['float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'int64']
#
# Missing Values:
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_freq_our                 0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# word_freq_lab                 0
# word_freq_labs                0
# word_freq_telnet              0
# word_freq_857                 0
# word_freq_data                0
# word_freq_415                 0
# word_freq_85                  0
# word_freq_technology          0
# word_freq_1999                0
# word_freq_parts               0
# word_freq_pm                  0
# word_freq_direct              0
# word_freq_cs                  0
# word_freq_meeting             0
# word_freq_original            0
# word_freq_project             0
# word_freq_re                  0
# word_freq_edu                 0
# word_freq_table               0
# word_freq_conference          0
# char_freq_;                   0
# char_freq_(                   0
# char_freq_[                   0
# char_freq_!                   0
# char_freq_$                   0
# char_freq_#                   0
# capital_run_length_average    0
# capital_run_length_longest    0
# capital_run_length_total      0
# spam                          0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Single Value Columns:
# []
#
# Empty Columns:
# []
#
# Mixed Type Columns:
# []
#
# Numerical Summary:
#                                     Mean    Median      Mode       Std  \
# word_freq_make              4.725700e-17 -0.347922 -0.347922  1.000119
# word_freq_address           1.350200e-17 -0.248027 -0.248027  1.000119
# word_freq_all               2.700400e-17 -0.565245 -0.565245  1.000119
# word_freq_3d                0.000000e+00 -0.046644 -0.046644  1.000119
# word_freq_our               4.050600e-17 -0.473040 -0.473040  1.000119
# word_freq_over             -1.350200e-17 -0.350205 -0.350205  1.000119
# word_freq_remove            0.000000e+00 -0.295731 -0.295731  1.000119
# word_freq_internet         -1.350200e-17 -0.263265 -0.263265  1.000119
# word_freq_order             0.000000e+00 -0.325617 -0.325617  1.000119
# word_freq_mail             -8.776300e-17 -0.378366 -0.378366  1.000119
# word_freq_receive          -1.350200e-17 -0.307836 -0.307836  1.000119
# word_freq_will             -7.932425e-17 -0.425205 -0.640525  1.000119
# word_freq_people            6.751000e-18 -0.315759 -0.315759  1.000119
# word_freq_report           -1.687750e-17 -0.176899 -0.176899  1.000119
# word_freq_addresses         0.000000e+00 -0.185016 -0.185016  1.000119
# word_freq_free              0.000000e+00 -0.318305 -0.318305  1.000119
# word_freq_business          2.700400e-17 -0.325939 -0.325939  1.000119
# word_freq_email             0.000000e+00 -0.348856 -0.348856  1.000119
# word_freq_you              -6.751000e-17 -0.202634 -0.971626  1.000119
# word_freq_credit            1.350200e-17 -0.168068 -0.168068  1.000119
# word_freq_your              8.101200e-17 -0.452518 -0.704864  1.000119
# word_freq_font             -2.700400e-17 -0.122848 -0.122848  1.000119
# word_freq_000               2.700400e-17 -0.286433 -0.286433  1.000119
# word_freq_money            -4.050600e-17 -0.210737 -0.210737  1.000119
# word_freq_hp                5.400800e-17 -0.342410 -0.342410  1.000119
# word_freq_hpl              -4.050600e-17 -0.308500 -0.308500  1.000119
# word_freq_george            1.350200e-17 -0.208346 -0.208346  1.000119
# word_freq_650              -4.050600e-17 -0.240163 -0.240163  1.000119
# word_freq_lab              -2.025300e-17 -0.170587 -0.170587  1.000119
# word_freq_labs              1.350200e-17 -0.236121 -0.236121  1.000119
# word_freq_telnet           -2.700400e-17 -0.164102 -0.164102  1.000119
# word_freq_857               2.700400e-17 -0.149368 -0.149368  1.000119
# word_freq_data             -2.700400e-17 -0.179822 -0.179822  1.000119
# word_freq_415              -1.350200e-17 -0.151691 -0.151691  1.000119
# word_freq_85                2.025300e-17 -0.203473 -0.203473  1.000119
# word_freq_technology        2.700400e-17 -0.257148 -0.257148  1.000119
# word_freq_1999              2.700400e-17 -0.338037 -0.338037  1.000119
# word_freq_parts            -6.751000e-18 -0.061566 -0.061566  1.000119
# word_freq_pm                2.025300e-17 -0.187653 -0.187653  1.000119
# word_freq_direct           -2.700400e-17 -0.191804 -0.191804  1.000119
# word_freq_cs                0.000000e+00 -0.130233 -0.130233  1.000119
# word_freq_meeting           2.025300e-17 -0.178329 -0.178329  1.000119
# word_freq_original         -6.751000e-18 -0.210366 -0.210366  1.000119
# word_freq_project          -6.751000e-18 -0.131987 -0.131987  1.000119
# word_freq_re               -2.700400e-17 -0.306107 -0.306107  1.000119
# word_freq_edu              -8.101200e-17 -0.204025 -0.204025  1.000119
# word_freq_table            -6.751000e-18 -0.073094 -0.073094  1.000119
# word_freq_conference       -2.700400e-17 -0.116407 -0.116407  1.000119
# char_freq_;                 0.000000e+00 -0.160010 -0.160010  1.000119
# char_freq_(                -6.751000e-18 -0.259088 -0.525294  1.000119
# char_freq_[                 1.350200e-17 -0.164364 -0.164364  1.000119
# char_freq_!                -2.700400e-17 -0.314432 -0.333407  1.000119
# char_freq_$                -2.700400e-17 -0.317325 -0.317325  1.000119
# char_freq_#                 2.700400e-17 -0.105071 -0.105071  1.000119
# capital_run_length_average -1.350200e-17 -0.093138 -0.132270  1.000119
# capital_run_length_longest -1.350200e-17 -0.186110 -0.206155  1.000119
# capital_run_length_total   -2.700400e-17 -0.306640 -0.459409  1.000119
# spam                        3.988124e-01  0.000000  0.000000  0.489712
#
#                                  Min        Max        Q1        Q3  \
# word_freq_make             -0.347922  14.786962 -0.347922 -0.347922
# word_freq_address          -0.248027  31.191446 -0.248027 -0.248027
# word_freq_all              -0.565245   9.325045 -0.565245  0.288035
# word_freq_3d               -0.046644  31.609920 -0.046644 -0.046644
# word_freq_our              -0.473040  14.067688 -0.473040  0.123130
# word_freq_over             -0.350205  20.954338 -0.350205 -0.350205
# word_freq_remove           -0.295731  18.005710 -0.295731 -0.295731
# word_freq_internet         -0.263265  26.818861 -0.263265 -0.263265
# word_freq_order            -0.325617  18.319574 -0.325617 -0.325617
# word_freq_mail             -0.378366  27.311390 -0.378366 -0.088980
# word_freq_receive          -0.307836  13.865797 -0.307836 -0.307836
# word_freq_will             -0.640525  10.318122 -0.640525  0.300083
# word_freq_people           -0.315759  17.629575 -0.315759 -0.315759
# word_freq_report           -0.176899  28.722781 -0.176899 -0.176899
# word_freq_addresses        -0.185016  18.026294 -0.185016 -0.185016
# word_freq_free             -0.318305  24.761960 -0.318305 -0.158418
# word_freq_business         -0.325939  15.276707 -0.325939 -0.325939
# word_freq_email            -0.348856  16.451217 -0.348856 -0.348856
# word_freq_you              -0.971626   9.630281 -0.971626  0.566358
# word_freq_credit           -0.168068  35.794708 -0.168068 -0.168068
# word_freq_your             -0.704864   8.962600 -0.704864  0.408939
# word_freq_font             -0.122848  15.841584 -0.122848 -0.122848
# word_freq_000              -0.286433  15.227610 -0.286433 -0.286433
# word_freq_money            -0.210737  28.746485 -0.210737 -0.210737
# word_freq_hp               -0.342410  12.083473 -0.342410 -0.284247
# word_freq_hpl              -0.308500  18.091291 -0.308500 -0.308500
# word_freq_george           -0.208346  18.567856 -0.208346 -0.208346
# word_freq_650              -0.240163  16.738884 -0.240163 -0.240163
# word_freq_lab              -0.170587  24.589789 -0.170587 -0.170587
# word_freq_labs             -0.236121  13.142224 -0.236121 -0.236121
# word_freq_telnet           -0.164102  32.117172 -0.164102 -0.164102
# word_freq_857              -0.149368  15.679706 -0.149368 -0.149368
# word_freq_data             -0.179822  31.766586 -0.179822 -0.179822
# word_freq_415              -0.151691  15.621584 -0.151691 -0.151691
# word_freq_85               -0.203473  37.518154 -0.203473 -0.203473
# word_freq_technology       -0.257148  19.643254 -0.257148 -0.257148
# word_freq_1999             -0.338037  15.894442 -0.338037 -0.338037
# word_freq_parts            -0.061566  36.079675 -0.061566 -0.061566
# word_freq_pm               -0.187653  24.614885 -0.187653 -0.187653
# word_freq_direct           -0.191804  14.707319 -0.191804 -0.191804
# word_freq_cs               -0.130233  22.312762 -0.130233 -0.130233
# word_freq_meeting          -0.178329  17.813146 -0.178329 -0.178329
# word_freq_original         -0.210366  15.187935 -0.210366 -0.210366
# word_freq_project          -0.131987  30.826844 -0.131987 -0.131987
# word_freq_re               -0.306107  20.176013 -0.306107 -0.143550
# word_freq_edu              -0.204025  23.551696 -0.204025 -0.204025
# word_freq_table            -0.073094  27.339376 -0.073094 -0.073094
# word_freq_conference       -0.116407  33.386042 -0.116407 -0.116407
# char_freq_;                -0.160010  17.206130 -0.160010 -0.160010
# char_freq_(                -0.525294  35.036886 -0.525294  0.182157
# char_freq_[                -0.164364  38.438324 -0.164364 -0.164364
# char_freq_!                -0.333407  38.183179 -0.333407  0.059136
# char_freq_$                -0.317325  24.728571 -0.317325 -0.096197
# char_freq_#                -0.105071  45.387561 -0.105071 -0.105071
# capital_run_length_average -0.132270  33.102078 -0.113338 -0.050603
# capital_run_length_longest -0.256265  49.794230 -0.226199 -0.040790
# capital_run_length_total   -0.469109  25.137870 -0.406061 -0.028181
# spam                        0.000000   1.000000  0.000000  1.000000
#
#                                 Range   Skewness     Kurtosis
# word_freq_make              15.134884   5.869855    54.351406
# word_freq_address           31.439474  13.464664   306.685973
# word_freq_all                9.890290   2.980623    12.941447
# word_freq_3d                31.656564  27.209539   788.370058
# word_freq_our               14.540727   4.696946    37.064801
# word_freq_over              21.304542   6.122653    71.603267
# word_freq_remove            18.301440   6.808707    76.381647
# word_freq_internet          27.082125   9.734232   167.550219
# word_freq_order             18.645191   5.284306    48.011373
# word_freq_mail              27.689756   8.568579   162.539033
# word_freq_receive           14.173634   5.078281    34.656119
# word_freq_will              10.958647   2.828005    12.096068
# word_freq_people            17.945334   6.889952    82.596297
# word_freq_report            28.899680  11.564142   219.645155
# word_freq_addresses         18.211310   7.513375    69.493809
# word_freq_free              25.080265   9.387745   157.691742
# word_freq_business          15.602646   5.567668    43.514184
# word_freq_email             16.800073   5.453867    48.157461
# word_freq_you               10.601906   1.524251     4.998066
# word_freq_credit            35.962776  15.430174   424.685771
# word_freq_your               9.667464   2.245707     8.094203
# word_freq_font              15.964433   9.541533    99.666089
# word_freq_000               15.514042   5.859524    49.119948
# word_freq_money             28.957222  15.556682   340.175773
# word_freq_hp                12.425883   5.638834    43.182446
# word_freq_hpl               18.399792   6.297471    63.072871
# word_freq_george            18.776201   9.481582   111.099824
# word_freq_650               16.979046   6.517998    58.669248
# word_freq_lab               24.760376  11.683591   189.408655
# word_freq_labs              13.378345   6.380831    49.105349
# word_freq_telnet            32.281274  13.514852   302.369897
# word_freq_857               15.829075  10.432463   128.295774
# word_freq_data              31.946407  13.069355   290.736221
# word_freq_415               15.773275  10.339838   126.437150
# word_freq_85                37.721627  16.001762   491.541633
# word_freq_technology        19.900402   7.358775    79.988044
# word_freq_1999              16.232479   5.126620    40.887964
# word_freq_parts             36.141241  27.078694   836.229272
# word_freq_pm                24.802538  11.762303   205.959198
# word_freq_direct            14.899123   9.101847   101.120159
# word_freq_cs                22.442995  11.468806   166.261694
# word_freq_meeting           17.991476   9.185157   108.994652
# word_freq_original          15.398301   7.408226    73.795377
# word_freq_project           30.958831  18.196824   449.017717
# word_freq_re                20.482120   8.917866   122.067523
# word_freq_edu               23.755721  10.077034   150.119541
# word_freq_table             27.412471  19.298485   431.309247
# word_freq_conference        33.502449  18.871757   492.146945
# char_freq_;                 17.366140  13.355885   200.449787
# char_freq_(                 35.562181  14.002666   404.370138
# char_freq_[                 38.602688  21.271982   664.620378
# char_freq_!                 38.516585  18.337278   579.438464
# char_freq_$                 25.045896  10.608970   188.462692
# char_freq_#                 45.492632  31.500180  1238.321018
# capital_run_length_average  33.234348  22.760655   614.399885
# capital_run_length_longest  50.050496  31.205495  1471.215610
# capital_run_length_total    25.606979   8.801641   146.108428
# spam                         1.000000   0.413450    -1.829929
#
# Categorical Summary:
# None
#
# Normality Test:
#                         Column  Statistic       P-Value      Result
# 0               word_freq_make   0.391597  3.199707e-80  Not Normal
# 1            word_freq_address   0.245179  6.266891e-85  Not Normal
# 2                word_freq_all   0.625975  4.199496e-70  Not Normal
# 3                 word_freq_3d   0.022374  9.314989e-91  Not Normal
# 4                word_freq_our   0.522228  4.159996e-75  Not Normal
# 5               word_freq_over   0.396125  4.631794e-80  Not Normal
# 6             word_freq_remove   0.328730  2.372652e-82  Not Normal
# 7           word_freq_internet   0.277378  5.752817e-84  Not Normal
# 8              word_freq_order   0.372535  6.917900e-81  Not Normal
# 9               word_freq_mail   0.409629  1.416054e-79  Not Normal
# 10           word_freq_receive   0.350853  1.271410e-81  Not Normal
# 11              word_freq_will   0.676375  3.152378e-67  Not Normal
# 12            word_freq_people   0.351302  1.316228e-81  Not Normal
# 13            word_freq_report   0.170970  5.091875e-87  Not Normal
# 14         word_freq_addresses   0.184898  1.220230e-86  Not Normal
# 15              word_freq_free   0.335980  4.090933e-82  Not Normal
# 16          word_freq_business   0.367839  4.773123e-81  Not Normal
# 17             word_freq_email   0.397476  5.174364e-80  Not Normal
# 18               word_freq_you   0.859290  7.002613e-52  Not Normal
# 19            word_freq_credit   0.155934  2.010491e-87  Not Normal
# 20              word_freq_your   0.733564  1.838597e-63  Not Normal
# 21              word_freq_font   0.102519  8.285392e-89  Not Normal
# 22               word_freq_000   0.321486  1.383616e-82  Not Normal
# 23             word_freq_money   0.192707  2.003296e-86  Not Normal
# 24                word_freq_hp   0.382732  1.561572e-80  Not Normal
# 25               word_freq_hpl   0.345715  8.572085e-82  Not Normal
# 26            word_freq_george   0.204823  4.358619e-86  Not Normal
# 27               word_freq_650   0.260332  1.760566e-84  Not Normal
# 28               word_freq_lab   0.161108  2.763586e-87  Not Normal
# 29              word_freq_labs   0.254096  1.148371e-84  Not Normal
# 30            word_freq_telnet   0.152537  1.632951e-87  Not Normal
# 31               word_freq_857   0.135541  5.831647e-88  Not Normal
# 32              word_freq_data   0.172521  5.609136e-87  Not Normal
# 33               word_freq_415   0.138530  6.980149e-88  Not Normal
# 34                word_freq_85   0.197752  2.765518e-86  Not Normal
# 35        word_freq_technology   0.278471  6.211978e-84  Not Normal
# 36              word_freq_1999   0.387613  2.315343e-80  Not Normal
# 37             word_freq_parts   0.034829  1.831203e-90  Not Normal
# 38                word_freq_pm   0.182508  1.049344e-86  Not Normal
# 39            word_freq_direct   0.189438  1.627021e-86  Not Normal
# 40                word_freq_cs   0.112720  1.503792e-88  Not Normal
# 41           word_freq_meeting   0.174857  6.490080e-87  Not Normal
# 42          word_freq_original   0.219317  1.119829e-85  Not Normal
# 43           word_freq_project   0.108941  1.205021e-88  Not Normal
# 44                word_freq_re   0.317464  1.027789e-82  Not Normal
# 45               word_freq_edu   0.205441  4.536252e-86  Not Normal
# 46             word_freq_table   0.046580  3.489249e-90  Not Normal
# 47        word_freq_conference   0.092448  4.626528e-89  Not Normal
# 48                 char_freq_;   0.134070  5.338696e-88  Not Normal
# 49                 char_freq_(   0.455128  7.243347e-78  Not Normal
# 50                 char_freq_[   0.139034  7.195285e-88  Not Normal
# 51                 char_freq_!   0.287749  1.196599e-83  Not Normal
# 52                 char_freq_$   0.323066  1.555717e-82  Not Normal
# 53                 char_freq_#   0.068090  1.156557e-89  Not Normal
# 54  capital_run_length_average   0.069365  1.242637e-89  Not Normal
# 55  capital_run_length_longest   0.174423  6.316469e-87  Not Normal
# 56    capital_run_length_total   0.420906  3.662205e-79  Not Normal
# 57                        spam   0.621564  2.441265e-70  Not Normal
#
# Outlier Summary:
#                         Column  Outlier Count
# 0               word_freq_make            982
# 1            word_freq_address            811
# 2                word_freq_all            297
# 3                 word_freq_3d             46
# 4                word_freq_our            449
# 5               word_freq_over            933
# 6             word_freq_remove            762
# 7           word_freq_internet            767
# 8              word_freq_order            722
# 9               word_freq_mail            748
# 10           word_freq_receive            651
# 11              word_freq_will            250
# 12            word_freq_people            806
# 13            word_freq_report            336
# 14         word_freq_addresses            305
# 15              word_freq_free            830
# 16          word_freq_business            906
# 17             word_freq_email            972
# 18               word_freq_you             58
# 19            word_freq_credit            389
# 20              word_freq_your            194
# 21              word_freq_font            112
# 22               word_freq_000            619
# 23             word_freq_money            659
# 24                word_freq_hp           1012
# 25               word_freq_hpl            789
# 26            word_freq_george            667
# 27               word_freq_650            452
# 28               word_freq_lab            359
# 29              word_freq_labs            456
# 30            word_freq_telnet            279
# 31               word_freq_857            196
# 32              word_freq_data            397
# 33               word_freq_415            206
# 34                word_freq_85            470
# 35        word_freq_technology            582
# 36              word_freq_1999            809
# 37             word_freq_parts             78
# 38                word_freq_pm            378
# 39            word_freq_direct            422
# 40                word_freq_cs            143
# 41           word_freq_meeting            335
# 42          word_freq_original            353
# 43           word_freq_project            317
# 44                word_freq_re            805
# 45               word_freq_edu            500
# 46             word_freq_table             60
# 47        word_freq_conference            201
# 48                 char_freq_;            750
# 49                 char_freq_(            255
# 50                 char_freq_[            505
# 51                 char_freq_!            373
# 52                 char_freq_$            730
# 53                 char_freq_#            702
# 54  capital_run_length_average            329
# 55  capital_run_length_longest            418
# 56    capital_run_length_total            497
# 57                        spam              0
#
# Correlation Matrix:
#                             word_freq_make  word_freq_address  word_freq_all  \
# word_freq_make                    1.000000           0.034012       0.063207
# word_freq_address                 0.034012           1.000000       0.027789
# word_freq_all                     0.063207           0.027789       1.000000
# word_freq_3d                      0.005388          -0.008947      -0.019901
# word_freq_our                     0.021740           0.036975       0.065676
# word_freq_over                    0.055067           0.005526       0.066547
# word_freq_remove                  0.011061           0.077374       0.028581
# word_freq_internet               -0.004370           0.013706       0.007221
# word_freq_order                   0.103842           0.053426       0.077561
# word_freq_mail                    0.040829           0.184304       0.025138
# word_freq_receive                 0.063031           0.060724       0.055647
# word_freq_will                    0.075911           0.026247       0.065733
# word_freq_people                  0.061985           0.015538       0.036431
# word_freq_report                  0.032263           0.012414       0.004900
# word_freq_addresses               0.022454           0.061826       0.104574
# word_freq_free                    0.065443           0.046630       0.061937
# word_freq_business                0.081471           0.022018       0.029834
# word_freq_email                   0.051571           0.178853       0.110794
# word_freq_you                     0.120563           0.055876       0.126502
# word_freq_credit                  0.020924          -0.006735       0.030874
# word_freq_your                    0.121458           0.117797       0.147895
# word_freq_font                   -0.025574           0.001214      -0.039464
# word_freq_000                     0.126478           0.007064       0.106694
# word_freq_money                   0.205689           0.061282       0.031150
# word_freq_hp                     -0.075054          -0.053573      -0.092684
# word_freq_hpl                    -0.063467          -0.044627      -0.066464
# word_freq_george                 -0.048086          -0.011228      -0.081297
# word_freq_650                    -0.050054          -0.033000      -0.051471
# word_freq_lab                    -0.041541          -0.026048      -0.057847
# word_freq_labs                   -0.054241          -0.029419      -0.030519
# word_freq_telnet                 -0.038899          -0.015937      -0.036610
# word_freq_857                    -0.031634           0.028852      -0.063579
# word_freq_data                   -0.042715          -0.032575      -0.058002
# word_freq_415                    -0.026322           0.026039      -0.063417
# word_freq_85                     -0.046083          -0.025524      -0.048968
# word_freq_technology             -0.057296          -0.028262      -0.047593
# word_freq_1999                   -0.058771           0.003749      -0.074329
# word_freq_parts                  -0.008626          -0.012708       0.031756
# word_freq_pm                     -0.011199          -0.016208      -0.017418
# word_freq_direct                 -0.035467           0.002326      -0.046013
# word_freq_cs                     -0.005280          -0.019350      -0.030822
# word_freq_meeting                -0.026546          -0.035908      -0.007620
# word_freq_original               -0.025603           0.037681      -0.052736
# word_freq_project                -0.022980          -0.029055      -0.056883
# word_freq_re                     -0.037848           0.020029      -0.056600
# word_freq_edu                    -0.034455          -0.026004      -0.060558
# word_freq_table                  -0.000950          -0.012337       0.027384
# word_freq_conference             -0.018904          -0.020947      -0.029465
# char_freq_;                      -0.027248           0.014735      -0.036778
# char_freq_(                      -0.019636          -0.028348      -0.024545
# char_freq_[                      -0.034784          -0.019436      -0.035805
# char_freq_!                       0.059184           0.031858       0.097316
# char_freq_$                       0.101957           0.044354       0.072944
# char_freq_#                      -0.009149           0.030669      -0.004520
# capital_run_length_average        0.044783           0.029355       0.095671
# capital_run_length_longest        0.059128           0.053870       0.092513
# capital_run_length_total          0.084127           0.034590       0.051961
# spam                              0.129194           0.100651       0.172350
#
#                             word_freq_3d  word_freq_our  word_freq_over  \
# word_freq_make                  0.005388       0.021740        0.055067
# word_freq_address              -0.008947       0.036975        0.005526
# word_freq_all                  -0.019901       0.065676        0.066547
# word_freq_3d                    1.000000       0.000256       -0.009163
# word_freq_our                   0.000256       1.000000        0.041392
# word_freq_over                 -0.009163       0.041392        1.000000
# word_freq_remove                0.014289       0.135957        0.046868
# word_freq_internet              0.003801       0.023411        0.079704
# word_freq_order                -0.001040       0.014483        0.097037
# word_freq_mail                 -0.003845       0.027233        0.010099
# word_freq_receive              -0.013191       0.079164        0.056592
# word_freq_will                 -0.018577       0.055007        0.001582
# word_freq_people               -0.013153       0.020657        0.067278
# word_freq_report                0.003379       0.001586        0.007932
# word_freq_addresses             0.005375       0.048309        0.140009
# word_freq_free                  0.005798       0.079198        0.016681
# word_freq_business             -0.002827       0.137868        0.057684
# word_freq_email                 0.016561       0.050785        0.059196
# word_freq_you                  -0.009933       0.083092        0.083312
# word_freq_credit               -0.005006       0.027838        0.057502
# word_freq_your                  0.004577       0.142992        0.105693
# word_freq_font                  0.030589      -0.022715        0.006869
# word_freq_000                   0.014715       0.062136        0.181754
# word_freq_money                 0.025851       0.000321        0.059429
# word_freq_hp                   -0.015702      -0.076783       -0.086682
# word_freq_hpl                  -0.014030      -0.079807       -0.089520
# word_freq_george               -0.009710      -0.062482       -0.050811
# word_freq_650                  -0.010630      -0.064151       -0.067771
# word_freq_lab                  -0.007931       0.039627       -0.048898
# word_freq_labs                 -0.010911      -0.053613       -0.048262
# word_freq_telnet               -0.007654      -0.042054       -0.046347
# word_freq_857                  -0.006967      -0.024256       -0.036525
# word_freq_data                 -0.008246      -0.034749       -0.035031
# word_freq_415                  -0.006975      -0.024555       -0.037089
# word_freq_85                   -0.005907      -0.051058       -0.055394
# word_freq_technology           -0.006309      -0.052210       -0.054298
# word_freq_1999                 -0.007436      -0.077682       -0.060609
# word_freq_parts                -0.002723       0.133057       -0.018420
# word_freq_pm                   -0.004506      -0.045512       -0.049223
# word_freq_direct               -0.007654      -0.017580       -0.027722
# word_freq_cs                   -0.006075      -0.052325       -0.030898
# word_freq_meeting              -0.008318       0.107706       -0.056541
# word_freq_original             -0.009384      -0.054583       -0.037610
# word_freq_project              -0.006114       0.002771       -0.030174
# word_freq_re                   -0.013178      -0.049497       -0.057469
# word_freq_edu                  -0.009432      -0.083315       -0.034364
# word_freq_table                -0.003409      -0.028146       -0.014740
# word_freq_conference           -0.001861      -0.035040       -0.033478
# char_freq_;                    -0.000028      -0.035049       -0.021744
# char_freq_(                    -0.011443      -0.054580       -0.011584
# char_freq_[                    -0.007514      -0.027988       -0.016729
# char_freq_!                    -0.003867       0.019203        0.058121
# char_freq_$                     0.008273       0.040696        0.105927
# char_freq_#                     0.000134       0.002144        0.020413
# capital_run_length_average      0.005754       0.050832       -0.013554
# capital_run_length_longest      0.022105       0.042985        0.065709
# capital_run_length_total        0.023785      -0.010498        0.063403
# spam                            0.056383       0.230074        0.212311
#
#                             word_freq_remove  word_freq_internet  \
# word_freq_make                      0.011061           -0.004370
# word_freq_address                   0.077374            0.013706
# word_freq_all                       0.028581            0.007221
# word_freq_3d                        0.014289            0.003801
# word_freq_our                       0.135957            0.023411
# word_freq_over                      0.046868            0.079704
# word_freq_remove                    1.000000            0.033692
# word_freq_internet                  0.033692            1.000000
# word_freq_order                     0.049238            0.106890
# word_freq_mail                      0.055695            0.079045
# word_freq_receive                   0.186794            0.153180
# word_freq_will                     -0.008437           -0.006715
# word_freq_people                    0.003165            0.024114
# word_freq_report                   -0.023818            0.008944
# word_freq_addresses                 0.037437            0.072475
# word_freq_free                      0.135875            0.051863
# word_freq_business                  0.189654            0.219123
# word_freq_email                     0.115447            0.026383
# word_freq_you                       0.102589            0.016865
# word_freq_credit                    0.049675            0.115809
# word_freq_your                      0.143770            0.169658
# word_freq_font                     -0.002935           -0.017166
# word_freq_000                       0.068443            0.086645
# word_freq_money                     0.034547            0.035725
# word_freq_hp                       -0.094994           -0.055915
# word_freq_hpl                      -0.084666           -0.043949
# word_freq_george                   -0.060458           -0.049662
# word_freq_650                      -0.070265           -0.051532
# word_freq_lab                      -0.050260           -0.037514
# word_freq_labs                     -0.061300           -0.044698
# word_freq_telnet                   -0.047897           -0.036238
# word_freq_857                      -0.042702           -0.035442
# word_freq_data                     -0.043017           -0.040426
# word_freq_415                      -0.043140           -0.036067
# word_freq_85                       -0.055209           -0.035936
# word_freq_technology               -0.057351           -0.037253
# word_freq_1999                     -0.055920           -0.021792
# word_freq_parts                    -0.015446           -0.012536
# word_freq_pm                       -0.049424           -0.032031
# word_freq_direct                   -0.019709           -0.003241
# word_freq_cs                       -0.035875           -0.000495
# word_freq_meeting                  -0.052009           -0.045201
# word_freq_original                 -0.053141           -0.004679
# word_freq_project                  -0.036292           -0.031418
# word_freq_re                       -0.057273           -0.006606
# word_freq_edu                      -0.059125           -0.039204
# word_freq_table                    -0.018173           -0.006559
# word_freq_conference               -0.033250           -0.022399
# char_freq_;                        -0.034080           -0.028976
# char_freq_(                        -0.061318           -0.042751
# char_freq_[                        -0.029466           -0.021383
# char_freq_!                         0.050992            0.029031
# char_freq_$                         0.067236            0.053569
# char_freq_#                         0.049306           -0.008121
# capital_run_length_average          0.039174            0.009977
# capital_run_length_longest          0.050825            0.035603
# capital_run_length_total           -0.017081            0.036895
# spam                                0.334456            0.200666
#
#                             word_freq_order  word_freq_mail  ...  char_freq_;  \
# word_freq_make                     0.103842        0.040829  ...    -0.027248
# word_freq_address                  0.053426        0.184304  ...     0.014735
# word_freq_all                      0.077561        0.025138  ...    -0.036778
# word_freq_3d                      -0.001040       -0.003845  ...    -0.000028
# word_freq_our                      0.014483        0.027233  ...    -0.035049
# word_freq_over                     0.097037        0.010099  ...    -0.021744
# word_freq_remove                   0.049238        0.055695  ...    -0.034080
# word_freq_internet                 0.106890        0.079045  ...    -0.028976
# word_freq_order                    1.000000        0.123366  ...    -0.015004
# word_freq_mail                     0.123366        1.000000  ...     0.006772
# word_freq_receive                  0.154473        0.151164  ...    -0.032930
# word_freq_will                     0.020238        0.064128  ...    -0.031107
# word_freq_people                   0.023147        0.038601  ...    -0.024662
# word_freq_report                   0.064349        0.014868  ...    -0.019714
# word_freq_addresses                0.207484        0.165582  ...    -0.018728
# word_freq_free                     0.006237        0.024312  ...    -0.029989
# word_freq_business                 0.162744        0.080546  ...    -0.032765
# word_freq_email                    0.078442        0.022615  ...    -0.041258
# word_freq_you                      0.027922        0.085202  ...    -0.049833
# word_freq_credit                   0.122109        0.030860  ...    -0.021135
# word_freq_your                     0.174233        0.108403  ...    -0.062540
# word_freq_font                    -0.020825        0.007037  ...     0.418551
# word_freq_000                      0.114734        0.099829  ...    -0.029673
# word_freq_money                    0.099244        0.043056  ...    -0.020622
# word_freq_hp                      -0.073467       -0.046633  ...     0.029315
# word_freq_hpl                     -0.051349       -0.021444  ...     0.011646
# word_freq_george                  -0.051286       -0.045375  ...    -0.008355
# word_freq_650                     -0.059366        0.018535  ...    -0.026542
# word_freq_lab                     -0.045824       -0.026830  ...    -0.018859
# word_freq_labs                    -0.044502        0.004656  ...    -0.020702
# word_freq_telnet                  -0.040483       -0.024040  ...    -0.016378
# word_freq_857                     -0.034438       -0.013433  ...    -0.008190
# word_freq_data                    -0.014184       -0.041266  ...    -0.006118
# word_freq_415                     -0.033992       -0.012648  ...    -0.008712
# word_freq_85                      -0.043442       -0.020930  ...    -0.022448
# word_freq_technology              -0.059402       -0.017835  ...    -0.020177
# word_freq_1999                    -0.035758       -0.014922  ...     0.038030
# word_freq_parts                   -0.006109       -0.019323  ...     0.007664
# word_freq_pm                      -0.043060       -0.019142  ...     0.027868
# word_freq_direct                  -0.006354        0.009621  ...    -0.018628
# word_freq_cs                      -0.037613       -0.025135  ...     0.046512
# word_freq_meeting                 -0.050166       -0.059711  ...    -0.008832
# word_freq_original                -0.041715        0.015801  ...     0.014303
# word_freq_project                 -0.036944       -0.028699  ...    -0.008014
# word_freq_re                      -0.079750       -0.036263  ...    -0.026397
# word_freq_edu                     -0.059767       -0.033743  ...     0.007729
# word_freq_table                    0.007770       -0.016474  ...     0.000209
# word_freq_conference              -0.027689       -0.018825  ...    -0.003110
# char_freq_;                       -0.015004        0.006772  ...     1.000000
# char_freq_(                       -0.037377       -0.004960  ...     0.044166
# char_freq_[                        0.017321        0.003800  ...     0.008972
# char_freq_!                        0.035937        0.031602  ...     0.013365
# char_freq_$                        0.152457        0.077405  ...     0.004075
# char_freq_#                       -0.002075        0.034482  ...     0.057212
# capital_run_length_average         0.110788        0.073128  ...     0.002778
# capital_run_length_longest         0.166299        0.101546  ...     0.042584
# capital_run_length_total           0.233198        0.078587  ...     0.055265
# spam                               0.221454        0.131686  ...    -0.067125
#
#                             char_freq_(  char_freq_[  char_freq_!  \
# word_freq_make                -0.019636    -0.034784     0.059184
# word_freq_address             -0.028348    -0.019436     0.031858
# word_freq_all                 -0.024545    -0.035805     0.097316
# word_freq_3d                  -0.011443    -0.007514    -0.003867
# word_freq_our                 -0.054580    -0.027988     0.019203
# word_freq_over                -0.011584    -0.016729     0.058121
# word_freq_remove              -0.061318    -0.029466     0.050992
# word_freq_internet            -0.042751    -0.021383     0.029031
# word_freq_order               -0.037377     0.017321     0.035937
# word_freq_mail                -0.004960     0.003800     0.031602
# word_freq_receive             -0.055898    -0.024788     0.030429
# word_freq_will                -0.039995    -0.049672     0.003277
# word_freq_people              -0.056985    -0.029961     0.034119
# word_freq_report              -0.007533    -0.015369    -0.012228
# word_freq_addresses           -0.008801    -0.001120     0.013835
# word_freq_free                -0.053892    -0.033461     0.108318
# word_freq_business            -0.044085    -0.040177     0.073476
# word_freq_email               -0.041793    -0.017194     0.033041
# word_freq_you                 -0.144989    -0.072106     0.147263
# word_freq_credit              -0.029684    -0.011679     0.047917
# word_freq_your                -0.091598    -0.048670     0.087063
# word_freq_font                -0.050066    -0.001565    -0.006929
# word_freq_000                 -0.039022     0.000428     0.065797
# word_freq_money               -0.032198    -0.020599     0.050250
# word_freq_hp                   0.113098     0.042761    -0.095756
# word_freq_hpl                  0.118253     0.067899    -0.081821
# word_freq_george               0.038722     0.002912    -0.054054
# word_freq_650                  0.287816     0.036297    -0.066261
# word_freq_lab                  0.130422     0.008918    -0.043090
# word_freq_labs                 0.193265     0.006585    -0.064876
# word_freq_telnet               0.195810     0.012852    -0.046245
# word_freq_857                  0.275541     0.018577    -0.043197
# word_freq_data                 0.025915     0.123387    -0.050454
# word_freq_415                  0.274220     0.018400    -0.039864
# word_freq_85                   0.167846     0.039573    -0.050440
# word_freq_technology           0.208631     0.002104    -0.064636
# word_freq_1999                 0.084304     0.076797    -0.069975
# word_freq_parts               -0.012101     0.001845    -0.016105
# word_freq_pm                   0.096923     0.041091    -0.027021
# word_freq_direct               0.234530     0.016261    -0.032286
# word_freq_cs                   0.027994     0.046850    -0.026715
# word_freq_meeting             -0.016606     0.011351    -0.040241
# word_freq_original             0.057262     0.122188    -0.052969
# word_freq_project             -0.004815    -0.011914    -0.035742
# word_freq_re                  -0.002435     0.009373     0.065917
# word_freq_edu                  0.014780    -0.003051    -0.030573
# word_freq_table               -0.004595    -0.004946    -0.018571
# word_freq_conference          -0.015248    -0.007225    -0.028550
# char_freq_;                    0.044166     0.008972     0.013365
# char_freq_(                    1.000000     0.022648    -0.038734
# char_freq_[                    0.022648     1.000000    -0.034912
# char_freq_!                   -0.038734    -0.034912     1.000000
# char_freq_$                    0.043627    -0.027330     0.136701
# char_freq_#                    0.024002    -0.007131     0.021098
# capital_run_length_average     0.032722    -0.009484     0.052682
# capital_run_length_longest     0.387573    -0.014622     0.072619
# capital_run_length_total       0.112663     0.007228     0.025249
# spam                          -0.106572    -0.070397     0.233812
#
#                             char_freq_$  char_freq_#  \
# word_freq_make                 0.101957    -0.009149
# word_freq_address              0.044354     0.030669
# word_freq_all                  0.072944    -0.004520
# word_freq_3d                   0.008273     0.000134
# word_freq_our                  0.040696     0.002144
# word_freq_over                 0.105927     0.020413
# word_freq_remove               0.067236     0.049306
# word_freq_internet             0.053569    -0.008121
# word_freq_order                0.152457    -0.002075
# word_freq_mail                 0.077405     0.034482
# word_freq_receive              0.086016     0.003485
# word_freq_will                 0.007014    -0.032553
# word_freq_people               0.213643    -0.015941
# word_freq_report               0.080100     0.005699
# word_freq_addresses            0.121817    -0.004507
# word_freq_free                 0.044005     0.039302
# word_freq_business             0.094859    -0.000817
# word_freq_email                0.061767     0.022420
# word_freq_you                  0.082557    -0.002867
# word_freq_credit               0.037316     0.008125
# word_freq_your                 0.149502    -0.002860
# word_freq_font                -0.011775     0.189439
# word_freq_000                  0.315913     0.020631
# word_freq_money                0.103525     0.001505
# word_freq_hp                  -0.092656     0.034141
# word_freq_hpl                 -0.085748    -0.021772
# word_freq_george              -0.063054    -0.016387
# word_freq_650                 -0.064882    -0.011842
# word_freq_lab                 -0.052770     0.002486
# word_freq_labs                -0.070393     0.056381
# word_freq_telnet              -0.049804     0.001534
# word_freq_857                 -0.046571    -0.010996
# word_freq_data                -0.050707    -0.011281
# word_freq_415                 -0.042099    -0.010883
# word_freq_85                  -0.051195    -0.009803
# word_freq_technology          -0.062435     0.008159
# word_freq_1999                -0.069166    -0.024181
# word_freq_parts               -0.014159    -0.004083
# word_freq_pm                  -0.047925    -0.012257
# word_freq_direct              -0.016176    -0.010273
# word_freq_cs                  -0.040471    -0.012823
# word_freq_meeting             -0.046226    -0.004345
# word_freq_original            -0.058823    -0.014691
# word_freq_project             -0.038760     0.000926
# word_freq_re                  -0.054418    -0.025247
# word_freq_edu                 -0.053094    -0.015947
# word_freq_table               -0.019618     0.000168
# word_freq_conference          -0.033212    -0.009290
# char_freq_;                    0.004075     0.057212
# char_freq_(                    0.043627     0.024002
# char_freq_[                   -0.027330    -0.007131
# char_freq_!                    0.136701     0.021098
# ...
# word_freq_george                             -0.020183
# word_freq_650                                -0.014953
# word_freq_lab                                -0.015838
# word_freq_labs                               -0.018109
# word_freq_telnet                             -0.012518
# word_freq_857                                -0.011590
# word_freq_data                               -0.016300
# word_freq_415                                -0.002355
# word_freq_85                                 -0.014840
# word_freq_technology                         -0.021243
# word_freq_1999                               -0.017142
# word_freq_parts                              -0.006303
# word_freq_pm                                 -0.015142
# word_freq_direct                             -0.006746
# word_freq_cs                                 -0.011067
# word_freq_meeting                            -0.018797
# word_freq_original                           -0.018950
# word_freq_project                            -0.013841
# word_freq_re                                 -0.028759
# word_freq_edu                                -0.018991
# word_freq_table                              -0.006781
# word_freq_conference                         -0.008792
# char_freq_;                                   0.002778
# char_freq_(                                   0.032722
# char_freq_[                                  -0.009484
# char_freq_!                                   0.052682
# char_freq_$                                   0.083635
# char_freq_#                                   0.013525
# capital_run_length_average                    1.000000
# capital_run_length_longest                    0.499447
# capital_run_length_total                      0.162626
# spam                                          0.110274
#
#                             capital_run_length_longest  \
# word_freq_make                                0.059128
# word_freq_address                             0.053870
# word_freq_all                                 0.092513
# word_freq_3d                                  0.022105
# word_freq_our                                 0.042985
# word_freq_over                                0.065709
# word_freq_remove                              0.050825
# word_freq_internet                            0.035603
# word_freq_order                               0.166299
# word_freq_mail                                0.101546
# word_freq_receive                             0.086208
# word_freq_will                                0.013574
# word_freq_people                              0.032936
# word_freq_report                              0.055736
# word_freq_addresses                           0.176836
# word_freq_free                                0.025523
# word_freq_business                            0.061003
# word_freq_email                               0.055629
# word_freq_you                                -0.002903
# word_freq_credit                              0.085389
# word_freq_your                                0.087475
# word_freq_font                                0.028514
# word_freq_000                                 0.107208
# word_freq_money                               0.044175
# word_freq_hp                                 -0.051517
# word_freq_hpl                                -0.051930
# word_freq_george                             -0.043754
# word_freq_650                                -0.038709
# word_freq_lab                                -0.034471
# word_freq_labs                               -0.039252
# word_freq_telnet                             -0.028484
# word_freq_857                                -0.027917
# word_freq_data                               -0.025790
# word_freq_415                                -0.024178
# word_freq_85                                 -0.030366
# word_freq_technology                         -0.038751
# word_freq_1999                               -0.035222
# word_freq_parts                              -0.009784
# word_freq_pm                                 -0.029975
# word_freq_direct                             -0.006550
# word_freq_cs                                 -0.024584
# word_freq_meeting                            -0.034916
# word_freq_original                           -0.023830
# word_freq_project                            -0.026465
# word_freq_re                                 -0.053555
# word_freq_edu                                -0.034364
# word_freq_table                              -0.010183
# word_freq_conference                         -0.017371
# char_freq_;                                   0.042584
# char_freq_(                                   0.387573
# char_freq_[                                  -0.014622
# char_freq_!                                   0.072619
# char_freq_$                                   0.188864
# char_freq_#                                   0.064546
# capital_run_length_average                    0.499447
# capital_run_length_longest                    1.000000
# capital_run_length_total                      0.464514
# spam                                          0.203657
#
#                             capital_run_length_total      spam
# word_freq_make                              0.084127  0.129194
# word_freq_address                           0.034590  0.100651
# word_freq_all                               0.051961  0.172350
# word_freq_3d                                0.023785  0.056383
# word_freq_our                              -0.010498  0.230074
# word_freq_over                              0.063403  0.212311
# word_freq_remove                           -0.017081  0.334456
# word_freq_internet                          0.036895  0.200666
# word_freq_order                             0.233198  0.221454
# word_freq_mail                              0.078587  0.131686
# word_freq_receive                           0.122057  0.272451
# word_freq_will                              0.004599 -0.014606
# word_freq_people                            0.090242  0.118024
# word_freq_report                            0.153939  0.053534
# word_freq_addresses                         0.132484  0.183849
# word_freq_free                             -0.003013  0.279261
# word_freq_business                          0.057109  0.260773
# word_freq_email                             0.030280  0.188321
# word_freq_you                              -0.027298  0.256242
# word_freq_credit                            0.063523  0.186074
# word_freq_your                              0.047364  0.394392
# word_freq_font                              0.105218  0.093727
# word_freq_000                               0.157330  0.325716
# word_freq_money                             0.081323  0.205045
# word_freq_hp                               -0.045403 -0.270024
# word_freq_hpl                              -0.062773 -0.242411
# word_freq_george                           -0.080950 -0.168925
# word_freq_650                              -0.070811 -0.164727
# word_freq_lab                              -0.057905 -0.137913
# word_freq_labs                             -0.067065 -0.180638
# word_freq_telnet                           -0.047253 -0.130764
# word_freq_857                              -0.048248 -0.120141
# word_freq_data                              0.007065 -0.124025
# word_freq_415                              -0.045611 -0.118373
# word_freq_85                               -0.047362 -0.154754
# word_freq_technology                       -0.047641 -0.145356
# word_freq_1999                             -0.005995 -0.201597
# word_freq_parts                            -0.015230 -0.034275
# word_freq_pm                               -0.052763 -0.129383
# word_freq_direct                           -0.029950 -0.061989
# word_freq_cs                               -0.026031 -0.105920
# word_freq_meeting                          -0.059456 -0.142813
# word_freq_original                         -0.044064 -0.146063
# word_freq_project                          -0.043103 -0.099406
# word_freq_re                               -0.101349 -0.152895
# word_freq_edu                              -0.049118 -0.152805
# word_freq_table                             0.003558 -0.046481
# word_freq_conference                       -0.011919 -0.089188
# char_freq_;                                 0.055265 -0.067125
# char_freq_(                                 0.112663 -0.106572
# char_freq_[                                 0.007228 -0.070397
# char_freq_!                                 0.025249  0.233812
# char_freq_$                                 0.205982  0.326603
# char_freq_#                                 0.043002  0.070315
# capital_run_length_average                  0.162626  0.110274
# capital_run_length_longest                  0.464514  0.203657
# capital_run_length_total                    1.000000  0.231671
# spam                                        0.231671  1.000000
#
# [58 rows x 58 columns]
#
# Highly Correlated Features:
#         Feature1          Feature2  Correlation
# 0  word_freq_857     word_freq_415     0.994875
# 1  word_freq_857  word_freq_direct     0.824206
# 2  word_freq_415  word_freq_direct     0.820837
#
# Class Distribution:
# spam
# 0    2531
# 1    1679
# Name: count, dtype: int64
#
# Mutual Information:
#                        Feature  Mutual Information
# 0                  char_freq_!            0.186313
# 1   capital_run_length_longest            0.176213
# 2                  char_freq_$            0.168171
# 3   capital_run_length_average            0.149368
# 4             word_freq_remove            0.148136
# 5               word_freq_your            0.137358
# 6               word_freq_free            0.121173
# 7                 word_freq_hp            0.115808
# 8              word_freq_money            0.106501
# 9     capital_run_length_total            0.105008
# 10               word_freq_000            0.101674
# 11               word_freq_hpl            0.092691
# 12            word_freq_george            0.090820
# 13               word_freq_you            0.087596
# 14               word_freq_our            0.082834
# 15           word_freq_receive            0.064776
# 16               word_freq_all            0.063896
# 17           word_freq_address            0.062907
# 18            word_freq_credit            0.062009
# 19          word_freq_business            0.060507
# 20             word_freq_order            0.059001
# 21              word_freq_over            0.056515
# 22               word_freq_edu            0.055412
# 23          word_freq_internet            0.053078
# 24            word_freq_people            0.047774
# 25             word_freq_email            0.047709
# 26              word_freq_mail            0.047612
# 27              word_freq_labs            0.047588
# 28              word_freq_1999            0.046407
# 29              word_freq_will            0.043376
# 30                 char_freq_(            0.041282
# 31            word_freq_telnet            0.040737
# 32               word_freq_lab            0.039689
# 33           word_freq_meeting            0.039258
# 34                word_freq_re            0.036613
# 35                word_freq_85            0.036193
# 36         word_freq_addresses            0.034464
# 37                 char_freq_;            0.033723
# 38               word_freq_650            0.030891
# 39                 char_freq_#            0.030585
# 40              word_freq_make            0.028098
# 41              word_freq_data            0.027915
# 42               word_freq_415            0.026989
# 43               word_freq_857            0.021324
# 44          word_freq_original            0.020438
# 45           word_freq_project            0.020150
# 46        word_freq_technology            0.019876
# 47                word_freq_pm            0.019475
# 48                 char_freq_[            0.018486
# 49                word_freq_3d            0.017563
# 50              word_freq_font            0.017353
# 51            word_freq_report            0.011738
# 52                word_freq_cs            0.008493
# 53            word_freq_direct            0.007231
# 54             word_freq_parts            0.006587
# 55        word_freq_conference            0.005264
# 56             word_freq_table            0.000000
#
# ----- Generating Plots -----
# Feature Selection (Chi-Square):
#                        Feature        Score
# 6             word_freq_remove  1592.434694
# 22               word_freq_000  1559.323013
# 52                 char_freq_$  1415.192912
# 15              word_freq_free  1031.475236
# 10           word_freq_receive  1015.166081
# 20              word_freq_your   929.037168
# 24                word_freq_hp   896.480479
# 16          word_freq_business   878.357505
# 19            word_freq_credit   867.294063
# 23             word_freq_money   839.922022
# 25               word_freq_hpl   801.915421
# 14         word_freq_addresses   769.116697
# 51                 char_freq_!   690.303141
# 55  capital_run_length_longest   681.379772
# 7           word_freq_internet   643.926025
# 8              word_freq_order   634.073084
# 29              word_freq_labs   581.788024
# 26            word_freq_george   576.611856
# 5               word_freq_over   541.883426
# 36              word_freq_1999   506.157843
# 34                word_freq_85   495.515910
# 45               word_freq_edu   481.805858
# 56    capital_run_length_total   481.673102
# 41           word_freq_meeting   481.494092
# 27               word_freq_650   475.669110
# 4                word_freq_our   471.105778
# 28               word_freq_lab   469.402829
# 30            word_freq_telnet   438.672105
# 17             word_freq_email   427.986913
# 42          word_freq_original   426.956460
# 31               word_freq_857   406.819121
# 33               word_freq_415   388.887308
# 54  capital_run_length_average   387.043782
# 38                word_freq_pm   375.556493
# 40                word_freq_cs   362.668214
# 32              word_freq_data   360.126720
# 35        word_freq_technology   345.908776
# 44                word_freq_re   321.511058
# 43           word_freq_project   315.188360
# 21              word_freq_font   301.048779
# 47        word_freq_conference   287.680261
# 3                 word_freq_3d   286.926189
# 18               word_freq_you   284.501698
# 2                word_freq_all   221.240848
# 0               word_freq_make   201.969620
# 53                 char_freq_#   198.101949
# 9               word_freq_mail   192.951390
# 12            word_freq_people   185.724591
# 1            word_freq_address   171.954751
# 50                 char_freq_[   126.934482
# 46             word_freq_table   124.435881
# 48                 char_freq_;   118.548517
# 49                 char_freq_(    91.026250
# 39            word_freq_direct    84.343609
# 37             word_freq_parts    80.331399
# 13            word_freq_report    68.203575
# 11              word_freq_will     1.402105
# Train:(2946, 10) Val:(421, 10) Test:(843, 10)
# --- Validation ---
# Accuracy : 0.8788598574821853
# Precision: 0.8784635783844018
# Recall   : 0.8788598574821853
# F1       : 0.8784086464228548
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       252
#            1       0.86      0.83      0.85       169
#
#     accuracy                           0.88       421
#    macro avg       0.88      0.87      0.87       421
# weighted avg       0.88      0.88      0.88       421
# --- Test ---
# Accuracy : 0.8896797153024911
# Precision: 0.8895489320722096
# Recall   : 0.8896797153024911
# F1       : 0.889324125015769
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       488
#            1       0.89      0.85      0.87       355
#
#     accuracy                           0.89       843
#    macro avg       0.89      0.88      0.89       843
# weighted avg       0.89      0.89      0.89       843
